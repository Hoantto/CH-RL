# %%
import math
import networkx as nx
import random
from datetime import datetime

# %%
G = nx.Graph()
graph = open("road-minnesota.txt","r")
# importance priority queue
imp_pq = list()
order = 0

# %%
def Connect(G, graph):
    # get number of nodes and edges
    graph_parameters = graph.readline().split()
    vertices_number = int(graph_parameters[0],base=10)
    edges_number = int(graph_parameters[1],base=10)
    print(vertices_number)
    print(edges_number)
    # add nodes to networkx graph
    for i in range(vertices_number):
        G.add_node(i+1, contracted = False,imp=0,level=0,contr_neighbours=0)
    # add edges to networkx graph
    edge = graph.readline()
    while edge:
        edge_parameters = edge.split()
        source_node = int(edge_parameters[0], base=10)
        target_node = int(edge_parameters[1], base=10)
        edge_weight = 1
        found_exist = False
        for i in G[source_node]:
            # already store the edge with different weight, choose the min weight
            if i == target_node:
                G[source_node][target_node]['weight'] = min(G[source_node][target_node]['weight'],edge_weight)
                found_exist = True
                break
        if not found_exist:
            G.add_edge(source_node,target_node,weight=edge_weight)
        edge = graph.readline()

# %%
def SetOrder(G, imp_pq, n):
    # initialize imp_pq
    for i in range(n):
        imp_pq.append((GetImportance(G,i+1),i+1))
        # print("settled node %d"%(i+1))
    order = 1
    # for i in range(1000):
    #     print(imp_pq[i+1])
    lazy_update_counter = 0
    contracted_num = 0
    completed_rate = 0
    k = 0
    print("initializing importance queue settled.")
    while len(imp_pq)>0:
        # find current lowest importance node in imp_pq
        curr_node_imp_pair = min(imp_pq, key= lambda pair:pair[0])
        curr_node  = curr_node_imp_pair[1]   
        imp_pq.remove(curr_node_imp_pair)
        # get new importance for current lowest importance node
        new_imp = GetImportance(G,curr_node)
        # print("get new importance for node %d"%curr_node)
        # lazy update
        if((len(imp_pq) == 0) or (new_imp - min(imp_pq,key=lambda pair:pair[0])[0] <= 10) or (lazy_update_counter >= 5)):
            # print("update for node %d"%curr_node)
            lazy_update_counter = 0
            G.nodes[curr_node]['imp'] = order
            order +=1
            # contract node
            G.nodes[curr_node]['contracted'] = True
            ContractNode(G,curr_node,n)
            # print("already contracted node %d"%curr_node)
            contracted_num += 1
            k +=1
            if(contracted_num == n):
                print("contracted completed!")
            if(k == 100):
                completed_rate = contracted_num / n
                print(completed_rate)
                k = 0
        else:
            imp_pq.append((new_imp,curr_node))
            lazy_update_counter +=1
            # print("recalculated prority of node %d" %curr_node)

# %%
def GetImportance(G, x):
    # get number of incident edges of x
    edges_incident = len(G[x])
    # get number of added shortcut when simulate contracting node x
    shortcuts = 0
    seenBefore = list()
    for i in G[x]:
        for j in G[x]:
            pair = sorted((i,j))
            if (i==j or (pair in seenBefore)):continue
            seenBefore.append(pair)
            if((G.nodes[i]['contracted'] == False) and (G.nodes[j]['contracted'] == False)):
                shortcuts +=1
    edge_difference = shortcuts - edges_incident
    return edge_difference + 2*G.nodes[x]['contr_neighbours'] + G.nodes[x]['level']

# %%
def ContractNode(G, x, n):
    mx = GetMaxEdge(G, x)
    seenBefore = list()
    for i in G[x]:
        for j in G[x]:
            if ((G.nodes[i]['contracted'] == True) or (G.nodes[j]['contracted'])):
                continue
            pair = sorted((i,j))
            if (i==j or (pair in seenBefore)):continue
            seenBefore.append(pair)
            Check_Witness(G, n, i, x, mx)
            # print("check witness completed")
    # update importance term in incident node
    for i in G[x]:
        G.nodes[i]['contr_neighbours'] +=1
        G.nodes[i]['level'] = max(G.nodes[i]['level'], G.nodes[x]['level'] + 1)

# %%
def GetMaxEdge(G, x):
    ret = 0
    for i in G[x]:
        for j in G[x]:
            if((i != j) and (G.nodes[i]['contracted'] == False) and (G.nodes[j]['contracted'] == False)):
                ret = max(ret, G[x][i]['weight'] + G[x][j]['weight'])
    return ret

# %%
def Check_Witness(G, n, u, x, mx, type=None):
    # dijkstra priority queue for search witness path from u to v, excludes x
    # v is incident edge of x, excludes u
    D_pq = list()
    # initialize D_pq
    D_pq.append((0, u))
    # distance dictionary from u to any node in search tree
    D_dist = dict()
    # initialize D_dist
    D_dist[u] = 0
    # maximum iteration round for dijkstra search
    iter = int(250 * (n - order) / n)
    while((len(D_pq) > 0) and (iter > 0)):
        iter -=1
        curr_dist_pair = min(D_pq, key= lambda pair:pair[0])
        curr_dist = curr_dist_pair[0]
        a = curr_dist_pair[1]
        D_pq.remove(curr_dist_pair)
        if(curr_dist > D_dist[a]):
            continue
        for p in G[a]:
            new_dist = curr_dist + G[a][p]['weight']
            # p must not be x and not be contracted
            if(p != x and (G.nodes[p]['contracted'] == False)):
                # p must not be settled node or distance greater than new_dist
                if((p not in D_dist) or (D_dist[p] > new_dist)):
                    # prune when witness path greater than mx
                    if(p not in D_dist):
                        if new_dist < mx:
                            D_dist[p] = new_dist
                            D_pq.append((new_dist,p))
                    else:
                        if(D_dist[p] < mx):
                            D_dist[p] = new_dist
                            D_pq.append((new_dist,p))
    for v in G[x]:
        # v can not be u and not be contracted
        if ((v!=u) and (G.nodes[v]['contracted'] == False)):
            new_w = G[u][x]['weight'] + G[x][v]['weight']
            # print("%d %d %d"%(u,v,new_w))
            if((v not in D_dist) or (D_dist[v] > new_w)):
                # add shortcut
                # try:
                #     if(u,v) in G.edges:
                #         print("run here: no more add_edge")
                #         continue
                # except:
                G.add_edge(u,v,weight=new_w)
                # print("run here: add_edge:%d %d"%(u,v))

# %%
def GetDistance(G, s, t):
    # search with bi-dijkstra with ordering rank
    # initializing dijkstra from source node s
    SP_s = dict()
    parent_s = dict()
    unrelaxed_s = list()
    for node in G.nodes():
        SP_s[node] = math.inf
        parent_s[node] = None
        unrelaxed_s.append(node)
    SP_s[s] = 0
    # dijkstra forward
    while unrelaxed_s:
        node = min(unrelaxed_s, key= lambda node:SP_s[node])
        unrelaxed_s.remove(node)
        if SP_s[node] == math.inf:
            break
        # G[node] are the incident edges of node
        for child in G[node]:
            # skip unqualified edges
            if G.nodes[child]['imp'] < G.nodes[node]['imp']:
                continue
            distance = SP_s[node] + G[node][child]['weight']
            # relax edge
            if distance < SP_s[child]:
                SP_s[child] = distance
                parent_s[child] = node
    # initializing dijkstra from target node t
    SP_t = dict()
    parent_t = dict()
    unrelaxed_t = list()
    for node in G.nodes():
        SP_t[node] = math.inf
        parent_t[node] = None
        unrelaxed_t.append(node)
    SP_t[t] = 0

    # dijkstra backward
    while unrelaxed_t:
        node = min(unrelaxed_t, key= lambda node: SP_t[node])
        unrelaxed_t.remove(node)
        if SP_t[node] == math.inf:
            break
        # G[node] are the incident edges of node
        for child in G[node]:
            # skip unqualified edges
            if G.nodes[child]['imp'] < G.nodes[node]['imp']:
                continue
            distance = SP_t[node] + G[node][child]['weight']
            if distance < SP_t[child]:
                SP_t[child] = distance
                parent_t[child] = node
    minimum = math.inf
    merge_node = None
    for i in SP_s:
        if SP_t[i] == math.inf:
            continue
        if SP_t[i] + SP_s[i] < minimum:
            minimum = SP_s[i] + SP_t[i]
            merge_node = i
    return minimum, merge_node, SP_s, SP_t, parent_s, parent_t

# %%
# see the route from origin of dijkstra to a given node
def Route_dijkstra(parent, node):
    route = []
    while node != None:
        route.append(node)
        node = parent[node]
    return route[::-1]

# %%
def See_full_route(G, s, t):
    minimum, merge_node, SP_s, SP_t, parent_s, parent_t = GetDistance(G, s, t)
    print("shortest distance between source node %d to target node %d:"%(s,t))
    if minimum == math.inf:
        print("no path between source node %d to target node %d"%(s,t))
        return
    has_path_list.append([s,t])
    print(minimum)
    route_from_source = Route_dijkstra(parent_s, merge_node)
    # show route
    print("route from source node %d:"%s)
    print(route_from_source)
    route_from_target = Route_dijkstra(parent_t, merge_node)
    # show route
    print("route from target node %d:"%t)
    print(route_from_target)
    route = route_from_source + route_from_target[::-1][1:]
    # show route
    print("entire route:")
    print(route)
    unvisited = 0
    for s_node, s_dist in SP_s.items():
        for t_node, t_dist in SP_t.items():
            if s_node == t_node and s_dist == t_dist == math.inf:
                unvisited += 1
    print(f"""we have skipped {unvisited} nodes from a graph with {len(G)}, 
    so we have skipped {unvisited/len(G)*100}% of the nodes in our search space.""")
    print("\n\n")

# %%
Connect(G, graph)
# Out:
# 2642
# 3303

# %%
edges_before = [*G.edges()]

# %%
# G.nodes.data()
for i in range(100):
    print(i+1,G.nodes[i+1])
# Out:
# 1 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 2 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 3 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 4 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 5 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 6 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 7 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 8 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 9 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 10 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 11 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 12 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 13 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 14 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 15 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 16 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 17 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 18 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 19 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 20 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 21 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 22 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 23 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 24 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 25 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 26 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 27 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 28 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 29 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 30 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 31 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 32 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 33 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 34 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 35 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 36 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 37 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 38 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 39 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 40 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 41 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 42 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 43 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 44 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 45 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 46 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 47 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 48 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 49 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 50 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 51 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 52 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 53 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 54 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 55 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 56 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 57 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 58 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 59 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 60 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 61 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 62 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 63 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 64 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 65 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 66 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 67 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 68 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 69 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 70 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 71 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 72 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 73 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 74 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 75 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 76 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 77 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 78 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 79 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 80 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 81 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 82 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 83 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 84 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 85 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 86 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 87 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 88 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 89 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 90 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 91 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 92 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 93 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 94 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 95 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 96 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 97 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 98 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 99 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 100 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}

# %%
SetOrder(G, imp_pq, len(G.nodes))
# Out:
# initializing importance queue settled.
# 0.03785011355034065
# 0.0757002271006813
# 0.11355034065102196
# 0.1514004542013626
# 0.18925056775170326
# 0.22710068130204392
# 0.26495079485238454
# 0.3028009084027252
# 0.34065102195306585
# 0.3785011355034065
# 0.41635124905374715
# 0.45420136260408783
# 0.49205147615442846
# 0.5299015897047691
# 0.5677517032551098
# 0.6056018168054504
# 0.6434519303557911
# 0.6813020439061317
# 0.7191521574564723
# 0.757002271006813
# 0.7948523845571537
# 0.8327024981074943
# 0.8705526116578349
# 0.9084027252081757
# 0.9462528387585163
# 0.9841029523088569
# contracted completed!

# %%
edges_after = [*G.edges()]
print("# edges before", len(edges_before))
print("# edges after", len(edges_after))
# Out:
# # edges before 3303
# # edges after 7453

# %%
added_edges = list(set(edges_after) - set(edges_before))
added_edges
# Out:
# [(690, 855),
#  (2450, 2487),
#  (2134, 2297),
#  (1745, 1797),
#  (913, 934),
#  (2293, 2336),
#  (1656, 1766),
#  (2087, 2118),
#  (1608, 1728),
#  (2069, 2076),
#  (1867, 1917),
#  (48, 86),
#  (104, 115),
#  (945, 984),
#  (341, 874),
#  (1131, 1143),
#  (1813, 1867),
#  (490, 506),
#  (2110, 2259),
#  (702, 728),
#  (153, 202),
#  (2491, 2519),
#  (2188, 2491),
#  (1301, 1435),
#  (196, 229),
#  (1762, 1951),
#  (1020, 1034),
#  (806, 874),
#  (589, 815),
#  (326, 458),
#  (1346, 1367),
#  (1419, 1463),
#  (560, 571),
#  (1470, 1610),
#  (137, 164),
#  (1315, 1382),
#  (2347, 2534),
#  (606, 742),
#  (19, 639),
#  (1570, 1756),
#  (391, 411),
#  (2450, 2478),
#  (582, 704),
#  (470, 549),
#  (788, 861),
#  (2110, 2123),
#  (1451, 1466),
#  (540, 544),
#  (1929, 2079),
#  (119, 269),
#  (1476, 1483),
#  (1171, 1183),
#  (1744, 1766),
#  (2004, 2188),
#  (2131, 2227),
#  (274, 281),
#  (129, 140),
#  (1826, 1951),
#  (1933, 2009),
#  (457, 527),
#  (1435, 1554),
#  (202, 305),
#  (1134, 1624),
#  (1241, 1831),
#  (2245, 2298),
#  (1390, 1408),
#  (1360, 1390),
#  (898, 933),
#  (1836, 1847),
#  (150, 160),
#  (560, 562),
#  (815, 913),
#  (945, 1487),
#  (1718, 1730),
#  (341, 538),
#  (582, 680),
#  (712, 717),
#  (1390, 1395),
#  (608, 814),
#  (1710, 1817),
#  (1784, 1797),
#  (1905, 1944),
#  (1315, 1554),
#  (483, 489),
#  (229, 245),
#  (1331, 1334),
#  (2188, 2192),
#  (599, 608),
#  (507, 511),
#  (2036, 2099),
#  (2166, 2175),
#  (2131, 2251),
#  (274, 385),
#  (1430, 1470),
#  (1451, 1459),
#  (2071, 2245),
#  (388, 393),
#  (249, 351),
#  (1598, 1620),
#  (213, 567),
#  (2336, 2349),
#  (2262, 2298),
#  (608, 711),
#  (1416, 1428),
#  (2182, 2293),
#  (129, 133),
#  (1862, 2137),
#  (2405, 2548),
#  (591, 680),
#  (546, 645),
#  (1608, 1964),
#  (633, 690),
#  (685, 793),
#  (2374, 2401),
#  (760, 806),
#  (137, 214),
#  (10, 19),
#  (2334, 2347),
#  (1596, 1652),
#  (1741, 1767),
#  (2561, 2579),
#  (1554, 1608),
#  (1826, 1912),
#  (65, 148),
#  [378, 1162],
#  [957, 1796],
#  [1412, 1590],
#  [510, 1435],
#  [377, 2332],
#  [833, 1792],
#  [507, 1317],
#  [445, 2101],
#  [390, 1084],
#  [1045, 1743],
#  [993, 1785],
#  [2398, 2559],
#  [644, 1481],
#  [590, 2015],
#  [35, 41],
#  [1368, 2046],
#  [1173, 2226],
#  [892, 2539],
#  [564, 1183],
#  [2131, 2464],
#  [719, 1306],
#  [79, 2636],
#  [1067, 1924],
#  [2323, 2472],
#  [346, 1207],
#  [160, 1719],
#  [900, 2321],
#  [824, 1654],
#  [14, 1602],
#  [825, 1073],
#  [831, 1373],
#  [40, 1339],
#  [1926, 2138],
#  [552, 2470],
#  [302, 893],
#  [1662, 2432],
#  [74, 2373],
#  [1524, 2442],
#  [1034, 1726],
#  [474, 2554],
#  [978, 1575],
#  [365, 890],
#  [17, 619],
#  [1099, 1139],
#  [1246, 2314],
#  [1316, 2546],
#  [1919, 2331],
#  [923, 2356],
#  [1897, 2230],
#  [625, 1828],
#  [425, 1629],
#  [243, 999],
#  [193, 957],
#  [1225, 2361],
#  [290, 1514],
#  [676, 980],
#  [572, 975],
#  [1346, 2052],
#  [873, 2389],
#  [513, 1355],
#  [209, 1188],
#  [821, 2063],
#  [1333, 1535],
#  [608, 1629],
#  [840, 1769],
#  [1319, 2470],
#  [716, 908],
#  [2196, 2523],
#  [915, 1740],
#  [134, 330],
#  [1679, 1710],
#  [378, 453],
#  [878, 2103],
#  [835, 2031],
#  [940, 2479],
#  [404, 437],
#  [905, 2056],
#  [420, 824],
#  [1430, 2427]]

# %%
for i in range(100):
    See_full_route(G,query_list[i][0],query_list[i][1])
# Out:
# shortest distance between source node 442 to target node 1000:
# 35
# route from source node 442:
# [442, 414, 874]
# route from target node 1000:
# [1000, 1001, 945, 874]
# entire route:
# [442, 414, 874, 945, 1001, 1000]
# we have skipped 2580 nodes from a graph with 2642,
#     so we have skipped 97.65329295987888% of the nodes in our search space.
#
#
#
# shortest distance between source node 739 to target node 2234:
# 57
# route from source node 739:
# [739, 742, 976, 1782]
# route from target node 2234:
# [2234, 2262, 2245, 2071, 2110, 2099, 2137, 1782]
# entire route:
# [739, 742, 976, 1782, 2137, 2099, 2110, 2071, 2245, 2262, 2234]
# we have skipped 2568 nodes from a graph with 2642,
#     so we have skipped 97.19909159727479% of the nodes in our search space.
#
#
#
# shortest distance between source node 589 to target node 1495:
# 27
# route from source node 589:
# [589, 828]
# route from target node 1495:
# [1495, 1270, 1272, 1024, 828]
# entire route:
# [589, 828, 1024, 1272, 1270, 1495]
# we have skipped 2590 nodes from a graph with 2642,
#     so we have skipped 98.03179409538228% of the nodes in our search space.
#
#
#
# shortest distance between source node 531 to target node 1175:
# 31
# route from source node 531:
# [531, 535, 567, 828, 993]
# route from target node 1175:
# [1175, 1176, 1171, 1023, 993]
# entire route:
# [531, 535, 567, 828, 993, 1023, 1171, 1176, 1175]
# we have skipped 2559 nodes from a graph with 2642,
#     so we have skipped 96.85844057532172% of the nodes in our search space.
#
#
#
# shortest distance between source node 1359 to target node 1363:
# 32
# route from source node 1359:
# [1359, 1346, 1281, 1251, 1315]
# route from target node 1363:
# [1363, 1315]
# entire route:
# [1359, 1346, 1281, 1251, 1315, 1363]
# we have skipped 2575 nodes from a graph with 2642,
#     so we have skipped 97.46404239212718% of the nodes in our search space.
#
#
#
# shortest distance between source node 1215 to target node 2559:
# 32
# route from source node 1215:
# [1215, 1349, 1350]
# route from target node 2559:
# [2559, 2405, 2363, 2134, 1821, 1584, 1350]
# entire route:
# [1215, 1349, 1350, 1584, 1821, 2134, 2363, 2405, 2559]
# we have skipped 2543 nodes from a graph with 2642,
#     so we have skipped 96.25283875851628% of the nodes in our search space.
#
#
#
# shortest distance between source node 1467 to target node 2444:
# 30
# route from source node 1467:
# [1467, 1530, 1545, 1608, 1883, 2137]
# route from target node 2444:
# [2444, 2438, 2338, 2137]
# entire route:
# [1467, 1530, 1545, 1608, 1883, 2137, 2338, 2438, 2444]
# we have skipped 2554 nodes from a graph with 2642,
#     so we have skipped 96.66919000757002% of the nodes in our search space.
#
#
#
# shortest distance between source node 1021 to target node 1584:
# 27
# route from source node 1021:
# [1021, 1020, 1140, 976]
# route from target node 1584:
# [1584, 976]
# entire route:
# [1021, 1020, 1140, 976, 1584]
# we have skipped 2587 nodes from a graph with 2642,
#     so we have skipped 97.91824375473126% of the nodes in our search space.
#
#
#
# shortest distance between source node 1416 to target node 2083:
# 26
# route from source node 1416:
# [1416, 1428, 1430, 1574, 1788, 1883]
# route from target node 2083:
# [2083, 2087, 1951, 1883]
# entire route:
# [1416, 1428, 1430, 1574, 1788, 1883, 1951, 2087, 2083]
# we have skipped 2568 nodes from a graph with 2642,
#     so we have skipped 97.19909159727479% of the nodes in our search space.
#
#
#
# shortest distance between source node 636 to target node 1159:
# 23
# route from source node 636:
# [636, 641, 661, 667, 760, 874]
# route from target node 1159:
# [1159, 1172, 1173, 1174, 1152, 984, 874]
# entire route:
# [636, 641, 661, 667, 760, 874, 984, 1152, 1174, 1173, 1172, 1159]
# we have skipped 2536 nodes from a graph with 2642,
#     so we have skipped 95.9878879636639% of the nodes in our search space.
#
#
#
# shortest distance between source node 1970 to target node 2369:
# 20
# route from source node 1970:
# [1970, 1946, 1951, 2137]
# route from target node 2369:
# [2369, 2357, 2360, 2338, 2137]
# entire route:
# [1970, 1946, 1951, 2137, 2338, 2360, 2357, 2369]
# we have skipped 2552 nodes from a graph with 2642,
#     so we have skipped 96.59348978046934% of the nodes in our search space.
#
#
#
# shortest distance between source node 487 to target node 1500:
# 45
# route from source node 487:
# [487, 493, 507, 495, 639, 874]
# route from target node 1500:
# [1500, 1407, 1340, 874]
# entire route:
# [487, 493, 507, 495, 639, 874, 1340, 1407, 1500]
# we have skipped 2561 nodes from a graph with 2642,
#     so we have skipped 96.9341408024224% of the nodes in our search space.
#
#
#
# shortest distance between source node 293 to target node 1879:
# 45
# route from source node 293:
# [293, 341, 874]
# route from target node 1879:
# [1879, 1762, 1608, 874]
# entire route:
# [293, 341, 874, 1608, 1762, 1879]
# we have skipped 2565 nodes from a graph with 2642,
#     so we have skipped 97.08554125662377% of the nodes in our search space.
#
#
#
# shortest distance between source node 679 to target node 2141:
# 35
# route from source node 679:
# [679, 599, 608, 828, 993]
# route from target node 2141:
# [2141, 2119, 1964, 1821, 993]
# entire route:
# [679, 599, 608, 828, 993, 1821, 1964, 2119, 2141]
# we have skipped 2540 nodes from a graph with 2642,
#     so we have skipped 96.13928841786526% of the nodes in our search space.
#
#
#
# shortest distance between source node 91 to target node 1780:
# 63
# route from source node 91:
# [91, 152, 193, 213, 414, 874]
# route from target node 1780:
# [1780, 1771, 1608, 874]
# entire route:
# [91, 152, 193, 213, 414, 874, 1608, 1771, 1780]
# we have skipped 2534 nodes from a graph with 2642,
#     so we have skipped 95.91218773656321% of the nodes in our search space.
#
#
#
# shortest distance between source node 2518 to target node 2568:
# 22
# route from source node 2518:
# [2518, 2524, 2536, 2539, 2542, 2534]
# route from target node 2568:
# [2568, 2561, 2534]
# entire route:
# [2518, 2524, 2536, 2539, 2542, 2534, 2561, 2568]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 772 to target node 1592:
# 17
# route from source node 772:
# [772, 773, 843, 1542]
# route from target node 1592:
# [1592, 1542]
# entire route:
# [772, 773, 843, 1542, 1592]
# we have skipped 2577 nodes from a graph with 2642,
#     so we have skipped 97.53974261922785% of the nodes in our search space.
#
#
#
# shortest distance between source node 877 to target node 923:
# 24
# route from source node 877:
# [877, 901, 1024, 993]
# route from target node 923:
# [923, 913, 993]
# entire route:
# [877, 901, 1024, 993, 913, 923]
# we have skipped 2573 nodes from a graph with 2642,
#     so we have skipped 97.3883421650265% of the nodes in our search space.
#
#
#
# shortest distance between source node 1083 to target node 1616:
# 20
# route from source node 1083:
# [1083, 1109, 1356, 1350]
# route from target node 1616:
# [1616, 1608, 1554, 1350]
# entire route:
# [1083, 1109, 1356, 1350, 1554, 1608, 1616]
# we have skipped 2575 nodes from a graph with 2642,
#     so we have skipped 97.46404239212718% of the nodes in our search space.
#
#
#
# shortest distance between source node 1848 to target node 1926:
# 20
# route from source node 1848:
# [1848, 1847, 1930, 1968]
# route from target node 1926:
# [1926, 1928, 1940, 1951, 1968]
# entire route:
# [1848, 1847, 1930, 1968, 1951, 1940, 1928, 1926]
# we have skipped 2581 nodes from a graph with 2642,
#     so we have skipped 97.69114307342922% of the nodes in our search space.
#
#
#
# shortest distance between source node 886 to target node 1279:
# 20
# route from source node 886:
# [886, 899, 984]
# route from target node 1279:
# [1279, 1284, 1197, 1189, 1152, 984]
# entire route:
# [886, 899, 984, 1152, 1189, 1197, 1284, 1279]
# we have skipped 2572 nodes from a graph with 2642,
#     so we have skipped 97.35049205147615% of the nodes in our search space.
#
#
#
# shortest distance between source node 378 to target node 1162:
# 33
# route from source node 378:
# [378, 376, 391, 495, 639, 874]
# route from target node 1162:
# [1162, 1169, 1182, 1251, 874]
# entire route:
# [378, 376, 391, 495, 639, 874, 1251, 1182, 1169, 1162]
# we have skipped 2547 nodes from a graph with 2642,
#     so we have skipped 96.40423921271764% of the nodes in our search space.
#
#
#
# shortest distance between source node 957 to target node 1796:
# 29
# route from source node 957:
# [957, 976, 1350]
# route from target node 1796:
# [1796, 1797, 1745, 1788, 1350]
# entire route:
# [957, 976, 1350, 1788, 1745, 1797, 1796]
# we have skipped 2574 nodes from a graph with 2642,
#     so we have skipped 97.42619227857683% of the nodes in our search space.
#
#
#
# shortest distance between source node 1412 to target node 1590:
# 36
# route from source node 1412:
# [1412, 1419, 1470, 1608, 1782]
# route from target node 1590:
# [1590, 1821, 1782]
# entire route:
# [1412, 1419, 1470, 1608, 1782, 1821, 1590]
# we have skipped 2585 nodes from a graph with 2642,
#     so we have skipped 97.84254352763058% of the nodes in our search space.
#
#
#
# shortest distance between source node 510 to target node 1435:
# 25
# route from source node 510:
# [510, 503, 495, 639, 874]
# route from target node 1435:
# [1435, 1251, 874]
# entire route:
# [510, 503, 495, 639, 874, 1251, 1435]
# we have skipped 2579 nodes from a graph with 2642,
#     so we have skipped 97.61544284632853% of the nodes in our search space.
#
#
#
# shortest distance between source node 377 to target node 2332:
# 73
# route from source node 377:
# [377, 376, 391, 495, 639, 874]
# route from target node 2332:
# [2332, 2330, 2262, 2245, 2071, 2009, 1825, 874]
# entire route:
# [377, 376, 391, 495, 639, 874, 1825, 2009, 2071, 2245, 2262, 2330, 2332]
# we have skipped 2544 nodes from a graph with 2642,
#     so we have skipped 96.29068887206662% of the nodes in our search space.
#
#
#
# shortest distance between source node 833 to target node 1792:
# 40
# route from source node 833:
# [833, 832, 962, 985, 993]
# route from target node 1792:
# [1792, 1831, 993]
# entire route:
# [833, 832, 962, 985, 993, 1831, 1792]
# we have skipped 2546 nodes from a graph with 2642,
#     so we have skipped 96.3663890991673% of the nodes in our search space.
#
#
#
# shortest distance between source node 507 to target node 1317:
# 34
# route from source node 507:
# [507, 495, 639, 874]
# route from target node 1317:
# [1317, 1318, 1140, 874]
# entire route:
# [507, 495, 639, 874, 1140, 1318, 1317]
# we have skipped 2565 nodes from a graph with 2642,
#     so we have skipped 97.08554125662377% of the nodes in our search space.
#
#
#
# shortest distance between source node 445 to target node 2101:
# 43
# route from source node 445:
# [445, 442, 567, 828, 993, 2137]
# route from target node 2101:
# [2101, 2105, 2137]
# entire route:
# [445, 442, 567, 828, 993, 2137, 2105, 2101]
# we have skipped 2546 nodes from a graph with 2642,
#     so we have skipped 96.3663890991673% of the nodes in our search space.
#
#
#
# shortest distance between source node 390 to target node 1084:
# 50
# route from source node 390:
# [390, 389, 358, 405, 414, 874]
# route from target node 1084:
# [1084, 1074, 1152, 984, 874]
# entire route:
# [390, 389, 358, 405, 414, 874, 984, 1152, 1074, 1084]
# we have skipped 2578 nodes from a graph with 2642,
#     so we have skipped 97.5775927327782% of the nodes in our search space.
#
#
#
# shortest distance between source node 1045 to target node 1743:
# 26
# route from source node 1045:
# [1045, 976]
# route from target node 1743:
# [1743, 1730, 1821, 1584, 976]
# entire route:
# [1045, 976, 1584, 1821, 1730, 1743]
# we have skipped 2582 nodes from a graph with 2642,
#     so we have skipped 97.72899318697957% of the nodes in our search space.
#
#
#
# shortest distance between source node 993 to target node 1785:
# 11
# route from source node 993:
# [993]
# route from target node 1785:
# [1785, 1820, 1838, 1821, 993]
# entire route:
# [993, 1821, 1838, 1820, 1785]
# we have skipped 2590 nodes from a graph with 2642,
#     so we have skipped 98.03179409538228% of the nodes in our search space.
#
#
#
# shortest distance between source node 2398 to target node 2559:
# 52
# route from source node 2398:
# [2398, 2402, 2406, 2413, 2416, 2556, 2610, 2619, 2477, 2336, 2338]
# route from target node 2559:
# [2559, 2405, 2363, 2297, 2338]
# entire route:
# [2398, 2402, 2406, 2413, 2416, 2556, 2610, 2619, 2477, 2336, 2338, 2297, 2363, 2405, 2559]
# we have skipped 2541 nodes from a graph with 2642,
#     so we have skipped 96.1771385314156% of the nodes in our search space.
#
#
#
# shortest distance between source node 644 to target node 1481:
# 27
# route from source node 644:
# [644, 639, 874]
# route from target node 1481:
# [1481, 1475, 1448, 1331, 1251, 874]
# entire route:
# [644, 639, 874, 1251, 1331, 1448, 1475, 1481]
# we have skipped 2544 nodes from a graph with 2642,
#     so we have skipped 96.29068887206662% of the nodes in our search space.
#
#
#
# shortest distance between source node 590 to target node 2015:
# 33
# route from source node 590:
# [590, 591, 742, 976, 1782]
# route from target node 2015:
# [2015, 2005, 1782]
# entire route:
# [590, 591, 742, 976, 1782, 2005, 2015]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 35 to target node 41:
# 2
# route from source node 35:
# [35]
# route from target node 41:
# [41, 33, 35]
# entire route:
# [35, 33, 41]
# we have skipped 2589 nodes from a graph with 2642,
#     so we have skipped 97.99394398183195% of the nodes in our search space.
#
#
#
# shortest distance between source node 1368 to target node 2046:
# 30
# route from source node 1368:
# [1368, 1394, 1788, 1883]
# route from target node 2046:
# [2046, 1968, 1883]
# entire route:
# [1368, 1394, 1788, 1883, 1968, 2046]
# we have skipped 2560 nodes from a graph with 2642,
#     so we have skipped 96.89629068887207% of the nodes in our search space.
#
#
#
# shortest distance between source node 1173 to target node 2226:
# 44
# route from source node 1173:
# [1173, 1174, 1152, 1251, 1608]
# route from target node 2226:
# [2226, 2193, 2188, 1964, 1608]
# entire route:
# [1173, 1174, 1152, 1251, 1608, 1964, 2188, 2193, 2226]
# we have skipped 2540 nodes from a graph with 2642,
#     so we have skipped 96.13928841786526% of the nodes in our search space.
#
#
#
# shortest distance between source node 892 to target node 2539:
# 44
# route from source node 892:
# [892, 869, 976, 1782]
# route from target node 2539:
# [2539, 2542, 2338, 2137, 1782]
# entire route:
# [892, 869, 976, 1782, 2137, 2338, 2542, 2539]
# we have skipped 2550 nodes from a graph with 2642,
#     so we have skipped 96.51778955336866% of the nodes in our search space.
#
#
#
# shortest distance between source node 564 to target node 1183:
# 30
# route from source node 564:
# [564, 567, 828, 993]
# route from target node 1183:
# [1183, 1171, 1023, 993]
# entire route:
# [564, 567, 828, 993, 1023, 1171, 1183]
# we have skipped 2563 nodes from a graph with 2642,
#     so we have skipped 97.00984102952309% of the nodes in our search space.
#
#
#
# shortest distance between source node 2131 to target node 2464:
# 14
# route from source node 2131:
# [2131, 2134]
# route from target node 2464:
# [2464, 2460, 2297, 2134]
# entire route:
# [2131, 2134, 2297, 2460, 2464]
# we have skipped 2579 nodes from a graph with 2642,
#     so we have skipped 97.61544284632853% of the nodes in our search space.
#
#
#
# shortest distance between source node 719 to target node 1306:
# 26
# route from source node 719:
# [719, 729, 734, 742, 874]
# route from target node 1306:
# [1306, 1251, 874]
# entire route:
# [719, 729, 734, 742, 874, 1251, 1306]
# we have skipped 2558 nodes from a graph with 2642,
#     so we have skipped 96.82059046177139% of the nodes in our search space.
#
#
#
# shortest distance between source node 79 to target node 2636:
# 66
# route from source node 79:
# [79, 83, 153, 274, 567, 828, 993]
# route from target node 2636:
# [2636, 2576, 2534, 1821, 993]
# entire route:
# [79, 83, 153, 274, 567, 828, 993, 1821, 2534, 2576, 2636]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 1067 to target node 1924:
# 33
# route from source node 1067:
# [1067, 1070, 1315, 1825]
# route from target node 1924:
# [1924, 1915, 1930, 1825]
# entire route:
# [1067, 1070, 1315, 1825, 1930, 1915, 1924]
# we have skipped 2549 nodes from a graph with 2642,
#     so we have skipped 96.47993943981832% of the nodes in our search space.
#
#
#
# shortest distance between source node 2323 to target node 2472:
# 14
# route from source node 2323:
# [2323, 2324, 2339, 2336]
# route from target node 2472:
# [2472, 2468, 2477, 2336]
# entire route:
# [2323, 2324, 2339, 2336, 2477, 2468, 2472]
# we have skipped 2564 nodes from a graph with 2642,
#     so we have skipped 97.04769114307344% of the nodes in our search space.
#
#
#
# shortest distance between source node 346 to target node 1207:
# 31
# route from source node 346:
# [346, 391, 495, 639, 874]
# route from target node 1207:
# [1207, 1179, 1182, 1251, 874]
# entire route:
# [346, 391, 495, 639, 874, 1251, 1182, 1179, 1207]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 160 to target node 1719:
# 39
# route from source node 160:
# [160, 169, 281, 517]
# route from target node 1719:
# [1719, 1718, 1535, 901, 517]
# entire route:
# [160, 169, 281, 517, 901, 1535, 1718, 1719]
# we have skipped 2566 nodes from a graph with 2642,
#     so we have skipped 97.1233913701741% of the nodes in our search space.
#
#
#
# shortest distance between source node 900 to target node 2321:
# 32
# route from source node 900:
# [900, 912, 1079, 1024, 1241]
# route from target node 2321:
# [2321, 2347, 2232, 1821, 1241]
# entire route:
# [900, 912, 1079, 1024, 1241, 1821, 2232, 2347, 2321]
# we have skipped 2555 nodes from a graph with 2642,
#     so we have skipped 96.70704012112036% of the nodes in our search space.
#
#
#
# shortest distance between source node 824 to target node 1654:
# 35
# route from source node 824:
# [824, 941, 945, 1624]
# route from target node 1654:
# [1654, 1660, 1624]
# entire route:
# [824, 941, 945, 1624, 1660, 1654]
# we have skipped 2555 nodes from a graph with 2642,
#     so we have skipped 96.70704012112036% of the nodes in our search space.
#
#
#
# shortest distance between source node 14 to target node 1602:
# 68
# route from source node 14:
# [14, 15, 16, 35, 21, 19, 639, 874]
# route from target node 1602:
# [1602, 1598, 1487, 945, 874]
# entire route:
# [14, 15, 16, 35, 21, 19, 639, 874, 945, 1487, 1598, 1602]
# we have skipped 2546 nodes from a graph with 2642,
#     so we have skipped 96.3663890991673% of the nodes in our search space.
#
#
#
# shortest distance between source node 825 to target node 1073:
# 16
# route from source node 825:
# [825, 865, 895, 874]
# route from target node 1073:
# [1073, 1074, 1152, 984, 874]
# entire route:
# [825, 865, 895, 874, 984, 1152, 1074, 1073]
# we have skipped 2568 nodes from a graph with 2642,
#     so we have skipped 97.19909159727479% of the nodes in our search space.
#
#
#
# shortest distance between source node 831 to target node 1373:
# 46
# route from source node 831:
# [831, 828, 874]
# route from target node 1373:
# [1373, 1358, 1360, 1315, 874]
# entire route:
# [831, 828, 874, 1315, 1360, 1358, 1373]
# we have skipped 2548 nodes from a graph with 2642,
#     so we have skipped 96.44208932626798% of the nodes in our search space.
#
#
#
# shortest distance between source node 40 to target node 1339:
# 47
# route from source node 40:
# [40, 21, 19, 639, 874]
# route from target node 1339:
# [1339, 1337, 1219, 1140, 874]
# entire route:
# [40, 21, 19, 639, 874, 1140, 1219, 1337, 1339]
# we have skipped 2541 nodes from a graph with 2642,
#     so we have skipped 96.1771385314156% of the nodes in our search space.
#
#
#
# shortest distance between source node 1926 to target node 2138:
# 24
# route from source node 1926:
# [1926, 1928, 1929, 2005, 1964]
# route from target node 2138:
# [2138, 2130, 2131, 2134, 1964]
# entire route:
# [1926, 1928, 1929, 2005, 1964, 2134, 2131, 2130, 2138]
# we have skipped 2568 nodes from a graph with 2642,
#     so we have skipped 97.19909159727479% of the nodes in our search space.
#
#
#
# shortest distance between source node 552 to target node 2470:
# 57
# route from source node 552:
# [552, 577, 606, 828, 993, 2137]
# route from target node 2470:
# [2470, 2476, 2477, 2336, 2137]
# entire route:
# [552, 577, 606, 828, 993, 2137, 2336, 2477, 2476, 2470]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 302 to target node 893:
# 20
# route from source node 302:
# [302, 360, 497, 517]
# route from target node 893:
# [893, 902, 901, 517]
# entire route:
# [302, 360, 497, 517, 901, 902, 893]
# we have skipped 2558 nodes from a graph with 2642,
#     so we have skipped 96.82059046177139% of the nodes in our search space.
#
#
#
# shortest distance between source node 1662 to target node 2432:
# 33
# route from source node 1662:
# [1662, 1667, 1771, 2137]
# route from target node 2432:
# [2432, 2338, 2137]
# entire route:
# [1662, 1667, 1771, 2137, 2338, 2432]
# we have skipped 2552 nodes from a graph with 2642,
#     so we have skipped 96.59348978046934% of the nodes in our search space.
#
#
#
# shortest distance between source node 74 to target node 2373:
# 83
# route from source node 74:
# [74, 76, 77, 83, 153, 274, 567, 828, 993, 2137]
# route from target node 2373:
# [2373, 2395, 2401, 2374, 2349, 2336, 2137]
# entire route:
# [74, 76, 77, 83, 153, 274, 567, 828, 993, 2137, 2336, 2349, 2374, 2401, 2395, 2373]
# we have skipped 2545 nodes from a graph with 2642,
#     so we have skipped 96.32853898561694% of the nodes in our search space.
#
#
#
# shortest distance between source node 1524 to target node 2442:
# 29
# route from source node 1524:
# [1524, 1493, 1574, 1788, 1883, 2137]
# route from target node 2442:
# [2442, 2437, 2438, 2338, 2137]
# entire route:
# [1524, 1493, 1574, 1788, 1883, 2137, 2338, 2438, 2437, 2442]
# we have skipped 2553 nodes from a graph with 2642,
#     so we have skipped 96.63133989401969% of the nodes in our search space.
#
#
#
# shortest distance between source node 1034 to target node 1726:
# 24
# route from source node 1034:
# [1034, 1140, 1251, 1608]
# route from target node 1726:
# [1726, 1675, 1608]
# entire route:
# [1034, 1140, 1251, 1608, 1675, 1726]
# we have skipped 2589 nodes from a graph with 2642,
#     so we have skipped 97.99394398183195% of the nodes in our search space.
#
#
#
# shortest distance between source node 474 to target node 2554:
# 61
# route from source node 474:
# [474, 471, 424, 391, 495, 639, 815, 976]
# route from target node 2554:
# [2554, 2548, 2363, 2134, 1821, 1584, 976]
# entire route:
# [474, 471, 424, 391, 495, 639, 815, 976, 1584, 1821, 2134, 2363, 2548, 2554]
# we have skipped 2541 nodes from a graph with 2642,
#     so we have skipped 96.1771385314156% of the nodes in our search space.
#
#
#
# shortest distance between source node 978 to target node 1575:
# 13
# route from source node 978:
# [978, 976, 1350]
# route from target node 1575:
# [1575, 1574, 1350]
# entire route:
# [978, 976, 1350, 1574, 1575]
# we have skipped 2585 nodes from a graph with 2642,
#     so we have skipped 97.84254352763058% of the nodes in our search space.
#
#
#
# shortest distance between source node 365 to target node 890:
# 31
# route from source node 365:
# [365, 364, 358, 606, 742]
# route from target node 890:
# [890, 887, 742]
# entire route:
# [365, 364, 358, 606, 742, 887, 890]
# we have skipped 2576 nodes from a graph with 2642,
#     so we have skipped 97.50189250567752% of the nodes in our search space.
#
#
#
# shortest distance between source node 17 to target node 619:
# 27
# route from source node 17:
# [17, 35, 55, 90, 163, 281, 517]
# route from target node 619:
# [619, 625, 624, 517]
# entire route:
# [17, 35, 55, 90, 163, 281, 517, 624, 625, 619]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 1099 to target node 1139:
# 23
# route from source node 1099:
# [1099, 1153, 1197, 1189, 1152, 1140]
# route from target node 1139:
# [1139, 1143, 1131, 1140]
# entire route:
# [1099, 1153, 1197, 1189, 1152, 1140, 1131, 1143, 1139]
# we have skipped 2560 nodes from a graph with 2642,
#     so we have skipped 96.89629068887207% of the nodes in our search space.
#
#
#
# shortest distance between source node 1246 to target node 2314:
# 48
# route from source node 1246:
# [1246, 1193, 1152, 1140, 976]
# route from target node 2314:
# [2314, 2354, 2251, 2134, 1821, 1584, 976]
# entire route:
# [1246, 1193, 1152, 1140, 976, 1584, 1821, 2134, 2251, 2354, 2314]
# we have skipped 2559 nodes from a graph with 2642,
#     so we have skipped 96.85844057532172% of the nodes in our search space.
#
#
#
# shortest distance between source node 1316 to target node 2546:
# 54
# route from source node 1316:
# [1316, 1294, 1219, 1251, 1134]
# route from target node 2546:
# [2546, 2548, 2363, 2134, 1821, 1584, 1134]
# entire route:
# [1316, 1294, 1219, 1251, 1134, 1584, 1821, 2134, 2363, 2548, 2546]
# we have skipped 2535 nodes from a graph with 2642,
#     so we have skipped 95.95003785011355% of the nodes in our search space.
#
#
#
# shortest distance between source node 1919 to target node 2331:
# 33
# route from source node 1919:
# [1919, 1917, 1946, 1968]
# route from target node 2331:
# [2331, 2328, 2071, 2110, 1988, 1968]
# entire route:
# [1919, 1917, 1946, 1968, 1988, 2110, 2071, 2328, 2331]
# we have skipped 2582 nodes from a graph with 2642,
#     so we have skipped 97.72899318697957% of the nodes in our search space.
#
#
#
# shortest distance between source node 923 to target node 2356:
# 32
# route from source node 923:
# [923, 913, 993]
# route from target node 2356:
# [2356, 2363, 2134, 1821, 993]
# entire route:
# [923, 913, 993, 1821, 2134, 2363, 2356]
# we have skipped 2567 nodes from a graph with 2642,
#     so we have skipped 97.16124148372445% of the nodes in our search space.
#
#
#
# shortest distance between source node 1897 to target node 2230:
# 24
# route from source node 1897:
# [1897, 1921, 1954, 1968]
# route from target node 2230:
# [2230, 2097, 2071, 2110, 1988, 1968]
# entire route:
# [1897, 1921, 1954, 1968, 1988, 2110, 2071, 2097, 2230]
# we have skipped 2577 nodes from a graph with 2642,
#     so we have skipped 97.53974261922785% of the nodes in our search space.
#
#
#
# shortest distance between source node 625 to target node 1828:
# 44
# route from source node 625:
# [625, 624, 633, 690, 781, 1241, 1782]
# route from target node 1828:
# [1828, 1826, 1883, 1782]
# entire route:
# [625, 624, 633, 690, 781, 1241, 1782, 1883, 1826, 1828]
# we have skipped 2564 nodes from a graph with 2642,
#     so we have skipped 97.04769114307344% of the nodes in our search space.
#
#
#
# shortest distance between source node 425 to target node 1629:
# 55
# route from source node 425:
# [425, 376, 391, 495, 639, 874]
# route from target node 1629:
# [1629, 1624, 874]
# entire route:
# [425, 376, 391, 495, 639, 874, 1624, 1629]
# we have skipped 2561 nodes from a graph with 2642,
#     so we have skipped 96.9341408024224% of the nodes in our search space.
#
#
#
# shortest distance between source node 243 to target node 999:
# 28
# route from source node 243:
# [243, 244, 260, 345, 391, 495, 639, 874]
# route from target node 999:
# [999, 945, 874]
# entire route:
# [243, 244, 260, 345, 391, 495, 639, 874, 945, 999]
# we have skipped 2576 nodes from a graph with 2642,
#     so we have skipped 97.50189250567752% of the nodes in our search space.
#
#
#
# shortest distance between source node 193 to target node 957:
# 34
# route from source node 193:
# [193, 213, 414, 742, 976]
# route from target node 957:
# [957, 976]
# entire route:
# [193, 213, 414, 742, 976, 957]
# we have skipped 2566 nodes from a graph with 2642,
#     so we have skipped 97.1233913701741% of the nodes in our search space.
#
#
#
# shortest distance between source node 1225 to target node 2361:
# 40
# route from source node 1225:
# [1225, 1219, 1251, 1608, 1883, 2137]
# route from target node 2361:
# [2361, 2360, 2338, 2137]
# entire route:
# [1225, 1219, 1251, 1608, 1883, 2137, 2338, 2360, 2361]
# we have skipped 2540 nodes from a graph with 2642,
#     so we have skipped 96.13928841786526% of the nodes in our search space.
#
#
#
# shortest distance between source node 290 to target node 1514:
# 45
# route from source node 290:
# [290, 293, 341, 874]
# route from target node 1514:
# [1514, 1515, 1315, 874]
# entire route:
# [290, 293, 341, 874, 1315, 1515, 1514]
# we have skipped 2543 nodes from a graph with 2642,
#     so we have skipped 96.25283875851628% of the nodes in our search space.
#
#
#
# shortest distance between source node 676 to target node 980:
# 37
# route from source node 676:
# [676, 626, 606, 742, 874]
# route from target node 980:
# [980, 981, 945, 874]
# entire route:
# [676, 626, 606, 742, 874, 945, 981, 980]
# we have skipped 2548 nodes from a graph with 2642,
#     so we have skipped 96.44208932626798% of the nodes in our search space.
#
#
#
# shortest distance between source node 572 to target node 975:
# 34
# route from source node 572:
# [572, 560, 565, 639, 742, 828]
# route from target node 975:
# [975, 851, 843, 828]
# entire route:
# [572, 560, 565, 639, 742, 828, 843, 851, 975]
# we have skipped 2556 nodes from a graph with 2642,
#     so we have skipped 96.7448902346707% of the nodes in our search space.
#
#
#
# shortest distance between source node 1346 to target node 2052:
# 32
# route from source node 1346:
# [1346, 1394, 1350]
# route from target node 2052:
# [2052, 2131, 2134, 1821, 1584, 1350]
# entire route:
# [1346, 1394, 1350, 1584, 1821, 2134, 2131, 2052]
# we have skipped 2572 nodes from a graph with 2642,
#     so we have skipped 97.35049205147615% of the nodes in our search space.
#
#
#
# shortest distance between source node 873 to target node 2389:
# 38
# route from source node 873:
# [873, 875, 878, 866, 914, 930, 940, 993]
# route from target node 2389:
# [2389, 2418, 2347, 2232, 1821, 993]
# entire route:
# [873, 875, 878, 866, 914, 930, 940, 993, 1821, 2232, 2347, 2418, 2389]
# we have skipped 2551 nodes from a graph with 2642,
#     so we have skipped 96.555639666919% of the nodes in our search space.
#
#
#
# shortest distance between source node 513 to target node 1355:
# 41
# route from source node 513:
# [513, 527, 471, 424, 391, 495, 639, 815, 976]
# route from target node 1355:
# [1355, 1356, 976]
# entire route:
# [513, 527, 471, 424, 391, 495, 639, 815, 976, 1356, 1355]
# we have skipped 2550 nodes from a graph with 2642,
#     so we have skipped 96.51778955336866% of the nodes in our search space.
#
#
#
# shortest distance between source node 209 to target node 1188:
# 29
# route from source node 209:
# [209, 213, 567, 828]
# route from target node 1188:
# [1188, 1025, 1007, 828]
# entire route:
# [209, 213, 567, 828, 1007, 1025, 1188]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 821 to target node 2063:
# 31
# route from source node 821:
# [821, 874, 976, 1782]
# route from target node 2063:
# [2063, 1964, 1782]
# entire route:
# [821, 874, 976, 1782, 1964, 2063]
# we have skipped 2553 nodes from a graph with 2642,
#     so we have skipped 96.63133989401969% of the nodes in our search space.
#
#
#
# shortest distance between source node 1333 to target node 1535:
# 39
# route from source node 1333:
# [1333, 1331, 1251, 1134]
# route from target node 1535:
# [1535, 1542, 1134]
# entire route:
# [1333, 1331, 1251, 1134, 1542, 1535]
# we have skipped 2557 nodes from a graph with 2642,
#     so we have skipped 96.78274034822104% of the nodes in our search space.
#
#
#
# shortest distance between source node 608 to target node 1629:
# 51
# route from source node 608:
# [608, 734, 742, 874]
# route from target node 1629:
# [1629, 1624, 874]
# entire route:
# [608, 734, 742, 874, 1624, 1629]
# we have skipped 2569 nodes from a graph with 2642,
#     so we have skipped 97.23694171082514% of the nodes in our search space.
#
#
#
# shortest distance between source node 840 to target node 1769:
# 33
# route from source node 840:
# [840, 869, 976, 1350]
# route from target node 1769:
# [1769, 1753, 1761, 1763, 1762, 1788, 1350]
# entire route:
# [840, 869, 976, 1350, 1788, 1762, 1763, 1761, 1753, 1769]
# we have skipped 2580 nodes from a graph with 2642,
#     so we have skipped 97.65329295987888% of the nodes in our search space.
#
#
#
# shortest distance between source node 1319 to target node 2470:
# 36
# route from source node 1319:
# [1319, 1320, 1363, 1487, 1825]
# route from target node 2470:
# [2470, 2476, 2477, 2336, 1825]
# entire route:
# [1319, 1320, 1363, 1487, 1825, 2336, 2477, 2476, 2470]
# we have skipped 2546 nodes from a graph with 2642,
#     so we have skipped 96.3663890991673% of the nodes in our search space.
#
#
#
# shortest distance between source node 716 to target node 908:
# 7
# route from source node 716:
# [716, 756, 782, 855]
# route from target node 908:
# [908, 903, 855]
# entire route:
# [716, 756, 782, 855, 903, 908]
# we have skipped 2579 nodes from a graph with 2642,
#     so we have skipped 97.61544284632853% of the nodes in our search space.
#
#
#
# shortest distance between source node 2196 to target node 2523:
# 17
# route from source node 2196:
# [2196, 2491]
# route from target node 2523:
# [2523, 2542, 2491]
# entire route:
# [2196, 2491, 2542, 2523]
# we have skipped 2579 nodes from a graph with 2642,
#     so we have skipped 97.61544284632853% of the nodes in our search space.
#
#
#
# shortest distance between source node 915 to target node 1740:
# 40
# route from source node 915:
# [915, 959, 972, 1024, 1241, 1782]
# route from target node 1740:
# [1740, 1741, 1771, 1782]
# entire route:
# [915, 959, 972, 1024, 1241, 1782, 1771, 1741, 1740]
# we have skipped 2552 nodes from a graph with 2642,
#     so we have skipped 96.59348978046934% of the nodes in our search space.
#
#
#
# shortest distance between source node 134 to target node 330:
# 10
# route from source node 134:
# [134, 135, 141, 151]
# route from target node 330:
# [330, 295, 293, 151]
# entire route:
# [134, 135, 141, 151, 293, 295, 330]
# we have skipped 2582 nodes from a graph with 2642,
#     so we have skipped 97.72899318697957% of the nodes in our search space.
#
#
#
# shortest distance between source node 1679 to target node 1710:
# 3
# route from source node 1679:
# [1679, 1690, 1704, 1710]
# route from target node 1710:
# [1710]
# entire route:
# [1679, 1690, 1704, 1710]
# we have skipped 2580 nodes from a graph with 2642,
#     so we have skipped 97.65329295987888% of the nodes in our search space.
#
#
#
# shortest distance between source node 378 to target node 453:
# 11
# route from source node 378:
# [378, 393, 424]
# route from target node 453:
# [453, 452, 457, 424]
# entire route:
# [378, 393, 424, 457, 452, 453]
# we have skipped 2584 nodes from a graph with 2642,
#     so we have skipped 97.80469341408025% of the nodes in our search space.
#
#
#
# shortest distance between source node 878 to target node 2103:
# 33
# route from source node 878:
# [878, 866, 914, 930, 951, 1023, 1584, 2137]
# route from target node 2103:
# [2103, 2105, 2137]
# entire route:
# [878, 866, 914, 930, 951, 1023, 1584, 2137, 2105, 2103]
# we have skipped 2552 nodes from a graph with 2642,
#     so we have skipped 96.59348978046934% of the nodes in our search space.
#
#
#
# shortest distance between source node 835 to target node 2031:
# 36
# route from source node 835:
# [835, 836, 985, 993]
# route from target node 2031:
# [2031, 2036, 2087, 2079, 1964, 1821, 993]
# entire route:
# [835, 836, 985, 993, 1821, 1964, 2079, 2087, 2036, 2031]
# we have skipped 2541 nodes from a graph with 2642,
#     so we have skipped 96.1771385314156% of the nodes in our search space.
#
#
#
# shortest distance between source node 940 to target node 2479:
# 30
# route from source node 940:
# [940, 993]
# route from target node 2479:
# [2479, 2418, 2347, 2232, 1821, 993]
# entire route:
# [940, 993, 1821, 2232, 2347, 2418, 2479]
# we have skipped 2562 nodes from a graph with 2642,
#     so we have skipped 96.97199091597275% of the nodes in our search space.
#
#
#
# shortest distance between source node 404 to target node 437:
# 31
# route from source node 404:
# [404, 354, 351, 336, 341]
# route from target node 437:
# [437, 435, 391, 341]
# entire route:
# [404, 354, 351, 336, 341, 391, 435, 437]
# we have skipped 2582 nodes from a graph with 2642,
#     so we have skipped 97.72899318697957% of the nodes in our search space.
#
#
#
# shortest distance between source node 905 to target node 2056:
# 40
# route from source node 905:
# [905, 869, 976]
# route from target node 2056:
# [2056, 2035, 2033, 1736, 1730, 1821, 1584, 976]
# entire route:
# [905, 869, 976, 1584, 1821, 1730, 1736, 2033, 2035, 2056]
# we have skipped 2560 nodes from a graph with 2642,
#     so we have skipped 96.89629068887207% of the nodes in our search space.
#
#
#
# shortest distance between source node 420 to target node 824:
# 21
# route from source node 420:
# [420, 388, 391, 495, 639]
# route from target node 824:
# [824, 804, 760, 639]
# entire route:
# [420, 388, 391, 495, 639, 760, 804, 824]
# we have skipped 2569 nodes from a graph with 2642,
#     so we have skipped 97.23694171082514% of the nodes in our search space.
#
#
#
# shortest distance between source node 1430 to target node 2427:
# 34
# route from source node 1430:
# [1430, 1574, 1788, 1883, 2137]
# route from target node 2427:
# [2427, 2338, 2137]
# entire route:
# [1430, 1574, 1788, 1883, 2137, 2338, 2427]
# we have skipped 2567 nodes from a graph with 2642,
#     so we have skipped 97.16124148372445% of the nodes in our search space.

# %%
G_original = nx.Graph()
graph = open("road-euroroad.txt","r")
Connect(G_original,graph)
has_path_list = list()
# Out:
# 1174
# 1417

# %%
from networkx.algorithms.shortest_paths.weighted import single_source_dijkstra
single_source_dijkstra(G_original, 442, 1000)
# See_full_route(G,442,1001)
# Out:
# (17,
#  [442,
#   441,
#   440,
#   439,
#   438,
#   437,
#   436,
#   321,
#   320,
#   866,
#   297,
#   284,
#   277,
#   378,
#   377,
#   998,
#   999,
#   1000])

# %%
for i in range(100):
    print(i+1,G.nodes[i+1])
# Out:
# 1 {'contracted': True, 'imp': 1, 'level': 2, 'contr_neighbours': 1}
# 2 {'contracted': True, 'imp': 2, 'level': 5, 'contr_neighbours': 1}
# 3 {'contracted': True, 'imp': 3, 'level': 5, 'contr_neighbours': 2}
# 4 {'contracted': True, 'imp': 4, 'level': 5, 'contr_neighbours': 2}
# 5 {'contracted': True, 'imp': 5, 'level': 3, 'contr_neighbours': 1}
# 6 {'contracted': True, 'imp': 6, 'level': 2, 'contr_neighbours': 1}
# 7 {'contracted': True, 'imp': 1536, 'level': 3, 'contr_neighbours': 3}
# 8 {'contracted': True, 'imp': 7, 'level': 2, 'contr_neighbours': 1}
# 9 {'contracted': True, 'imp': 1537, 'level': 21, 'contr_neighbours': 4}
# 10 {'contracted': True, 'imp': 1538, 'level': 21, 'contr_neighbours': 4}
# 11 {'contracted': True, 'imp': 1539, 'level': 21, 'contr_neighbours': 5}
# 12 {'contracted': True, 'imp': 1540, 'level': 21, 'contr_neighbours': 6}
# 13 {'contracted': True, 'imp': 8, 'level': 21, 'contr_neighbours': 2}
# 14 {'contracted': True, 'imp': 9, 'level': 3, 'contr_neighbours': 1}
# 15 {'contracted': True, 'imp': 1541, 'level': 4, 'contr_neighbours': 3}
# 16 {'contracted': True, 'imp': 1542, 'level': 7, 'contr_neighbours': 3}
# 17 {'contracted': True, 'imp': 1543, 'level': 7, 'contr_neighbours': 4}
# 18 {'contracted': True, 'imp': 10, 'level': 21, 'contr_neighbours': 1}
# 19 {'contracted': True, 'imp': 2568, 'level': 29, 'contr_neighbours': 31}
# 20 {'contracted': True, 'imp': 1544, 'level': 21, 'contr_neighbours': 5}
# 21 {'contracted': True, 'imp': 2344, 'level': 21, 'contr_neighbours': 17}
# 22 {'contracted': True, 'imp': 11, 'level': 8, 'contr_neighbours': 2}
# 23 {'contracted': True, 'imp': 12, 'level': 6, 'contr_neighbours': 2}
# 24 {'contracted': True, 'imp': 13, 'level': 8, 'contr_neighbours': 2}
# 25 {'contracted': True, 'imp': 14, 'level': 2, 'contr_neighbours': 1}
# 26 {'contracted': True, 'imp': 1545, 'level': 4, 'contr_neighbours': 3}
# 27 {'contracted': True, 'imp': 1546, 'level': 5, 'contr_neighbours': 5}
# 28 {'contracted': True, 'imp': 15, 'level': 4, 'contr_neighbours': 2}
# 29 {'contracted': True, 'imp': 1547, 'level': 9, 'contr_neighbours': 7}
# 30 {'contracted': True, 'imp': 1548, 'level': 9, 'contr_neighbours': 4}
# 31 {'contracted': True, 'imp': 16, 'level': 5, 'contr_neighbours': 2}
# 32 {'contracted': True, 'imp': 2176, 'level': 8, 'contr_neighbours': 7}
# 33 {'contracted': True, 'imp': 1549, 'level': 7, 'contr_neighbours': 4}
# 34 {'contracted': True, 'imp': 17, 'level': 2, 'contr_neighbours': 1}
# 35 {'contracted': True, 'imp': 2177, 'level': 10, 'contr_neighbours': 9}
# 36 {'contracted': True, 'imp': 18, 'level': 9, 'contr_neighbours': 3}
# 37 {'contracted': True, 'imp': 19, 'level': 9, 'contr_neighbours': 2}
# 38 {'contracted': True, 'imp': 1550, 'level': 9, 'contr_neighbours': 5}
# 39 {'contracted': True, 'imp': 2446, 'level': 21, 'contr_neighbours': 17}
# 40 {'contracted': True, 'imp': 20, 'level': 8, 'contr_neighbours': 3}
# 41 {'contracted': True, 'imp': 21, 'level': 3, 'contr_neighbours': 2}
# 42 {'contracted': True, 'imp': 22, 'level': 6, 'contr_neighbours': 2}
# 43 {'contracted': True, 'imp': 23, 'level': 10, 'contr_neighbours': 2}
# 44 {'contracted': True, 'imp': 24, 'level': 6, 'contr_neighbours': 2}
# 45 {'contracted': True, 'imp': 1551, 'level': 21, 'contr_neighbours': 7}
# 46 {'contracted': True, 'imp': 25, 'level': 3, 'contr_neighbours': 1}
# 47 {'contracted': True, 'imp': 1552, 'level': 7, 'contr_neighbours': 5}
# 48 {'contracted': True, 'imp': 1553, 'level': 20, 'contr_neighbours': 5}
# 49 {'contracted': True, 'imp': 26, 'level': 3, 'contr_neighbours': 2}
# 50 {'contracted': True, 'imp': 1554, 'level': 21, 'contr_neighbours': 5}
# 51 {'contracted': True, 'imp': 2556, 'level': 29, 'contr_neighbours': 25}
# 52 {'contracted': True, 'imp': 27, 'level': 8, 'contr_neighbours': 2}
# 53 {'contracted': True, 'imp': 1555, 'level': 10, 'contr_neighbours': 7}
# 54 {'contracted': True, 'imp': 28, 'level': 10, 'contr_neighbours': 2}
# 55 {'contracted': True, 'imp': 2381, 'level': 21, 'contr_neighbours': 16}
# 56 {'contracted': True, 'imp': 29, 'level': 10, 'contr_neighbours': 2}
# 57 {'contracted': True, 'imp': 2293, 'level': 21, 'contr_neighbours': 10}
# 58 {'contracted': True, 'imp': 30, 'level': 6, 'contr_neighbours': 2}
# 59 {'contracted': True, 'imp': 31, 'level': 2, 'contr_neighbours': 1}
# 60 {'contracted': True, 'imp': 1556, 'level': 10, 'contr_neighbours': 3}
# 61 {'contracted': True, 'imp': 1557, 'level': 7, 'contr_neighbours': 4}
# 62 {'contracted': True, 'imp': 1558, 'level': 12, 'contr_neighbours': 7}
# 63 {'contracted': True, 'imp': 2178, 'level': 17, 'contr_neighbours': 10}
# 64 {'contracted': True, 'imp': 32, 'level': 4, 'contr_neighbours': 1}
# 65 {'contracted': True, 'imp': 2294, 'level': 22, 'contr_neighbours': 14}
# 66 {'contracted': True, 'imp': 33, 'level': 7, 'contr_neighbours': 2}
# 67 {'contracted': True, 'imp': 1559, 'level': 10, 'contr_neighbours': 4}
# 68 {'contracted': True, 'imp': 34, 'level': 12, 'contr_neighbours': 2}
# 69 {'contracted': True, 'imp': 35, 'level': 5, 'contr_neighbours': 2}
# 70 {'contracted': True, 'imp': 36, 'level': 11, 'contr_neighbours': 2}
# 71 {'contracted': True, 'imp': 37, 'level': 3, 'contr_neighbours': 2}
# 72 {'contracted': True, 'imp': 38, 'level': 8, 'contr_neighbours': 3}
# 73 {'contracted': True, 'imp': 39, 'level': 2, 'contr_neighbours': 1}
# 74 {'contracted': True, 'imp': 40, 'level': 8, 'contr_neighbours': 3}
# 75 {'contracted': True, 'imp': 41, 'level': 7, 'contr_neighbours': 3}
# 76 {'contracted': True, 'imp': 42, 'level': 8, 'contr_neighbours': 3}
# 77 {'contracted': True, 'imp': 1560, 'level': 11, 'contr_neighbours': 5}
# 78 {'contracted': True, 'imp': 43, 'level': 11, 'contr_neighbours': 2}
# 79 {'contracted': True, 'imp': 2295, 'level': 12, 'contr_neighbours': 10}
# 80 {'contracted': True, 'imp': 44, 'level': 11, 'contr_neighbours': 2}
# 81 {'contracted': True, 'imp': 2389, 'level': 21, 'contr_neighbours': 19}
# 82 {'contracted': True, 'imp': 1561, 'level': 18, 'contr_neighbours': 7}
# 83 {'contracted': True, 'imp': 2349, 'level': 15, 'contr_neighbours': 10}
# 84 {'contracted': True, 'imp': 45, 'level': 9, 'contr_neighbours': 2}
# 85 {'contracted': True, 'imp': 46, 'level': 10, 'contr_neighbours': 2}
# 86 {'contracted': True, 'imp': 47, 'level': 4, 'contr_neighbours': 3}
# 87 {'contracted': True, 'imp': 48, 'level': 3, 'contr_neighbours': 1}
# 88 {'contracted': True, 'imp': 1562, 'level': 20, 'contr_neighbours': 7}
# 89 {'contracted': True, 'imp': 49, 'level': 11, 'contr_neighbours': 2}
# 90 {'contracted': True, 'imp': 2405, 'level': 21, 'contr_neighbours': 15}
# 91 {'contracted': True, 'imp': 1563, 'level': 11, 'contr_neighbours': 6}
# 92 {'contracted': True, 'imp': 50, 'level': 12, 'contr_neighbours': 2}
# 93 {'contracted': True, 'imp': 1564, 'level': 17, 'contr_neighbours': 5}
# 94 {'contracted': True, 'imp': 2368, 'level': 15, 'contr_neighbours': 14}
# 95 {'contracted': True, 'imp': 51, 'level': 3, 'contr_neighbours': 2}
# 96 {'contracted': True, 'imp': 2179, 'level': 15, 'contr_neighbours': 7}
# 97 {'contracted': True, 'imp': 52, 'level': 2, 'contr_neighbours': 1}
# 98 {'contracted': True, 'imp': 53, 'level': 10, 'contr_neighbours': 2}
# 99 {'contracted': True, 'imp': 54, 'level': 3, 'contr_neighbours': 2}
# 100 {'contracted': True, 'imp': 55, 'level': 15, 'contr_neighbours': 2}

# %%
def See_full_route_constract(G, s, t):
    minimum, merge_node, SP_s, SP_t, parent_s, parent_t = GetDistance(G, s, t)
    # print("shortest distance between source node %d to target node %d:"%(s,t))
    if minimum == math.inf:
        print("no path between source node %d to target node %d"%(s,t))
        return
    # has_path_list.append([s,t])
    # print(minimum)
    route_from_source = Route_dijkstra(parent_s, merge_node)
    # show route
    # print("route from source node %d:"%s)
    # print(route_from_source)
    route_from_target = Route_dijkstra(parent_t, merge_node)
    # show route
    # print("route from target node %d:"%t)
    # print(route_from_target)
    route = route_from_source + route_from_target[::-1][1:]
    # show route
    # print("entire route:")
    # print(route)
    # unvisited = 0
    # for s_node, s_dist in SP_s.items():
    #     for t_node, t_dist in SP_t.items():
    #         if s_node == t_node and s_dist == t_dist == math.inf:
    #             unvisited += 1
    # print(f"""we have skipped {unvisited} nodes from a graph with {len(G)}, 
    # so we have skipped {unvisited/len(G)*100}% of the nodes in our search space.""")
    # print("\n\n")
    # print([minimum, route])

# %%
def dijkstra_with_contraction(G, source, destination, contracted = None):
    nx.set_node_attributes(G, {contracted: True}, 'contracted')
    
        
    shortest_path = dict()
    heap = list()
    
    for i in G.nodes():
        if not nx.get_node_attributes(G, 'contracted')[i]:
            shortest_path[i] = math.inf
            heap.append(i)
    shortest_path[source] = 0
    
    while len(heap)>0:
        q = min(heap, key= lambda node : shortest_path[node])
        if q == destination:
            nx.set_node_attributes(G, {contracted: False}, 'contracted')
            return shortest_path[q]
        heap.remove(q)
        # G[q] are incident edges of q
        for v in G[q]:
            # if the node is contracted, skip it
            if not nx.get_node_attributes(G, 'contracted')[v]:
                distance = shortest_path[q] + G[q][v]['weight']
                if distance < shortest_path[v]:
                    shortest_path[v] = distance
    nx.set_node_attributes(G, {contracted: False}, 'contracted')
    
    # can not reach the destination
    return math.inf

# %%
from networkx.algorithms.shortest_paths.weighted import single_source_dijkstra
sd_a = datetime.now()
for i in range(len(query_list)):
    distance = dijkstra_with_contraction(G_original, query_list[i][0], query_list[i][1])
sd_b = datetime.now()
((sd_b - sd_a).total_seconds())/len(query_list)
# Out:
# 1.90200824

# %%
ch_a = datetime.now()
for i in range(len(query_list)):
    See_full_route_constract(G, query_list[i][0], query_list[i][1])
ch_b = datetime.now()
((ch_b - ch_a).total_seconds())/len(query_list)
# Out:
# 0.03836821
