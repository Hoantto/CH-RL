# %%
import math
import networkx as nx
import random
from datetime import datetime

# %%
G = nx.Graph()
graph = open("road-euroroad.txt","r")
# importance priority queue
imp_pq = list()
order = 0

# %%
def Connect(G, graph):
    # get number of nodes and edges
    graph_parameters = graph.readline().split()
    vertices_number = int(graph_parameters[0],base=10)
    edges_number = int(graph_parameters[1],base=10)
    print(vertices_number)
    print(edges_number)
    # add nodes to networkx graph
    for i in range(vertices_number):
        G.add_node(i+1, contracted = False,imp=0,level=0,contr_neighbours=0)
    # add edges to networkx graph
    edge = graph.readline()
    while edge:
        edge_parameters = edge.split()
        source_node = int(edge_parameters[0], base=10)
        target_node = int(edge_parameters[1], base=10)
        edge_weight = 1
        found_exist = False
        for i in G[source_node]:
            # already store the edge with different weight, choose the min weight
            if i == target_node:
                G[source_node][target_node]['weight'] = min(G[source_node][target_node]['weight'],edge_weight)
                found_exist = True
                break
        if not found_exist:
            G.add_edge(source_node,target_node,weight=edge_weight)
        edge = graph.readline()

# %%
def SetOrder(G, imp_pq, n):
    # initialize imp_pq
    for i in range(n):
        imp_pq.append((GetImportance(G,i+1),i+1))
        # print("settled node %d"%(i+1))
    order = 1
    # for i in range(1000):
    #     print(imp_pq[i+1])
    lazy_update_counter = 0
    contracted_num = 0
    completed_rate = 0
    k = 0
    print("initializing importance queue settled.")
    while len(imp_pq)>0:
        # find current lowest importance node in imp_pq
        curr_node_imp_pair = min(imp_pq, key= lambda pair:pair[0])
        curr_node  = curr_node_imp_pair[1]   
        imp_pq.remove(curr_node_imp_pair)
        # get new importance for current lowest importance node
        new_imp = GetImportance(G,curr_node)
        # print("get new importance for node %d"%curr_node)
        # lazy update
        if((len(imp_pq) == 0) or (new_imp - min(imp_pq,key=lambda pair:pair[0])[0] <= 10) or (lazy_update_counter >= 5)):
            # print("update for node %d"%curr_node)
            lazy_update_counter = 0
            G.nodes[curr_node]['imp'] = order
            order +=1
            # contract node
            G.nodes[curr_node]['contracted'] = True
            ContractNode(G,curr_node,n)
            # print("already contracted node %d"%curr_node)
            contracted_num += 1
            k +=1
            if(contracted_num == n):
                print("contracted completed!")
            if(k == 100):
                completed_rate = contracted_num / n
                print(completed_rate)
                k = 0
        else:
            imp_pq.append((new_imp,curr_node))
            lazy_update_counter +=1
            # print("recalculated prority of node %d" %curr_node)

# %%
def GetImportance(G, x):
    # get number of incident edges of x
    edges_incident = len(G[x])
    # get number of added shortcut when simulate contracting node x
    shortcuts = 0
    seenBefore = list()
    for i in G[x]:
        for j in G[x]:
            pair = sorted((i,j))
            if (i==j or (pair in seenBefore)):continue
            seenBefore.append(pair)
            if((G.nodes[i]['contracted'] == False) and (G.nodes[j]['contracted'] == False)):
                shortcuts +=1
    edge_difference = shortcuts - edges_incident
    return edge_difference + 2*G.nodes[x]['contr_neighbours'] + G.nodes[x]['level']

# %%
def ContractNode(G, x, n):
    mx = GetMaxEdge(G, x)
    seenBefore = list()
    for i in G[x]:
        for j in G[x]:
            if ((G.nodes[i]['contracted'] == True) or (G.nodes[j]['contracted'])):
                continue
            pair = sorted((i,j))
            if (i==j or (pair in seenBefore)):continue
            seenBefore.append(pair)
            Check_Witness(G, n, i, x, mx)
            # print("check witness completed")
    # update importance term in incident node
    for i in G[x]:
        G.nodes[i]['contr_neighbours'] +=1
        G.nodes[i]['level'] = max(G.nodes[i]['level'], G.nodes[x]['level'] + 1)

# %%
def GetMaxEdge(G, x):
    ret = 0
    for i in G[x]:
        for j in G[x]:
            if((i != j) and (G.nodes[i]['contracted'] == False) and (G.nodes[j]['contracted'] == False)):
                ret = max(ret, G[x][i]['weight'] + G[x][j]['weight'])
    return ret

# %%
def Check_Witness(G, n, u, x, mx, type=None):
    # dijkstra priority queue for search witness path from u to v, excludes x
    # v is incident edge of x, excludes u
    D_pq = list()
    # initialize D_pq
    D_pq.append((0, u))
    # distance dictionary from u to any node in search tree
    D_dist = dict()
    # initialize D_dist
    D_dist[u] = 0
    # maximum iteration round for dijkstra search
    iter = int(250 * (n - order) / n)
    while((len(D_pq) > 0) and (iter > 0)):
        iter -=1
        curr_dist_pair = min(D_pq, key= lambda pair:pair[0])
        curr_dist = curr_dist_pair[0]
        a = curr_dist_pair[1]
        D_pq.remove(curr_dist_pair)
        if(curr_dist > D_dist[a]):
            continue
        for p in G[a]:
            new_dist = curr_dist + G[a][p]['weight']
            # p must not be x and not be contracted
            if(p != x and (G.nodes[p]['contracted'] == False)):
                # p must not be settled node or distance greater than new_dist
                if((p not in D_dist) or (D_dist[p] > new_dist)):
                    # prune when witness path greater than mx
                    if(p not in D_dist):
                        if new_dist < mx:
                            D_dist[p] = new_dist
                            D_pq.append((new_dist,p))
                    else:
                        if(D_dist[p] < mx):
                            D_dist[p] = new_dist
                            D_pq.append((new_dist,p))
    for v in G[x]:
        # v can not be u and not be contracted
        if ((v!=u) and (G.nodes[v]['contracted'] == False)):
            new_w = G[u][x]['weight'] + G[x][v]['weight']
            # print("%d %d %d"%(u,v,new_w))
            if((v not in D_dist) or (D_dist[v] > new_w)):
                # add shortcut
                # try:
                #     if(u,v) in G.edges:
                #         print("run here: no more add_edge")
                #         continue
                # except:
                G.add_edge(u,v,weight=new_w)
                # print("run here: add_edge:%d %d"%(u,v))

# %%
def GetDistance(G, s, t):
    # search with bi-dijkstra with ordering rank
    # initializing dijkstra from source node s
    SP_s = dict()
    parent_s = dict()
    unrelaxed_s = list()
    for node in G.nodes():
        SP_s[node] = math.inf
        parent_s[node] = None
        unrelaxed_s.append(node)
    SP_s[s] = 0
    # dijkstra forward
    while unrelaxed_s:
        node = min(unrelaxed_s, key= lambda node:SP_s[node])
        unrelaxed_s.remove(node)
        if SP_s[node] == math.inf:
            break
        # G[node] are the incident edges of node
        for child in G[node]:
            # skip unqualified edges
            if G.nodes[child]['imp'] < G.nodes[node]['imp']:
                continue
            distance = SP_s[node] + G[node][child]['weight']
            # relax edge
            if distance < SP_s[child]:
                SP_s[child] = distance
                parent_s[child] = node
    # initializing dijkstra from target node t
    SP_t = dict()
    parent_t = dict()
    unrelaxed_t = list()
    for node in G.nodes():
        SP_t[node] = math.inf
        parent_t[node] = None
        unrelaxed_t.append(node)
    SP_t[t] = 0

    # dijkstra backward
    while unrelaxed_t:
        node = min(unrelaxed_t, key= lambda node: SP_t[node])
        unrelaxed_t.remove(node)
        if SP_t[node] == math.inf:
            break
        # G[node] are the incident edges of node
        for child in G[node]:
            # skip unqualified edges
            if G.nodes[child]['imp'] < G.nodes[node]['imp']:
                continue
            distance = SP_t[node] + G[node][child]['weight']
            if distance < SP_t[child]:
                SP_t[child] = distance
                parent_t[child] = node
    minimum = math.inf
    merge_node = None
    for i in SP_s:
        if SP_t[i] == math.inf:
            continue
        if SP_t[i] + SP_s[i] < minimum:
            minimum = SP_s[i] + SP_t[i]
            merge_node = i
    return minimum, merge_node, SP_s, SP_t, parent_s, parent_t

# %%
# see the route from origin of dijkstra to a given node
def Route_dijkstra(parent, node):
    route = []
    while node != None:
        route.append(node)
        node = parent[node]
    return route[::-1]

# %%
def See_full_route(G, s, t):
    minimum, merge_node, SP_s, SP_t, parent_s, parent_t = GetDistance(G, s, t)
    print("shortest distance between source node %d to target node %d:"%(s,t))
    if minimum == math.inf:
        print("no path between source node %d to target node %d"%(s,t))
        return
    has_path_list.append([s,t])
    print(minimum)
    route_from_source = Route_dijkstra(parent_s, merge_node)
    # show route
    print("route from source node %d:"%s)
    print(route_from_source)
    route_from_target = Route_dijkstra(parent_t, merge_node)
    # show route
    print("route from target node %d:"%t)
    print(route_from_target)
    route = route_from_source + route_from_target[::-1][1:]
    # show route
    print("entire route:")
    print(route)
    unvisited = 0
    for s_node, s_dist in SP_s.items():
        for t_node, t_dist in SP_t.items():
            if s_node == t_node and s_dist == t_dist == math.inf:
                unvisited += 1
    print(f"""we have skipped {unvisited} nodes from a graph with {len(G)}, 
    so we have skipped {unvisited/len(G)*100}% of the nodes in our search space.""")
    print("\n\n")

# %%
Connect(G, graph)
# Out:
# 1174
# 1417

# %%
edges_before = [*G.edges()]

# %%
# G.nodes.data()
for i in range(100):
    print(i+1,G.nodes[i+1])
# Out:
# 1 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 2 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 3 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 4 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 5 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 6 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 7 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 8 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 9 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 10 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 11 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 12 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 13 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 14 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 15 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 16 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 17 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 18 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 19 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 20 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 21 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 22 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 23 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 24 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 25 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 26 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 27 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 28 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 29 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 30 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 31 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 32 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 33 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 34 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 35 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 36 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 37 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 38 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 39 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 40 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 41 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 42 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 43 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 44 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 45 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 46 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 47 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 48 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 49 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 50 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 51 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 52 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 53 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 54 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 55 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 56 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 57 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 58 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 59 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 60 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 61 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 62 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 63 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 64 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 65 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 66 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 67 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 68 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 69 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 70 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 71 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 72 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 73 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 74 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 75 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 76 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 77 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 78 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 79 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 80 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 81 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 82 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 83 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 84 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 85 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 86 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 87 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 88 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 89 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 90 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 91 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 92 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 93 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 94 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 95 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 96 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 97 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 98 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 99 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}
# 100 {'contracted': False, 'imp': 0, 'level': 0, 'contr_neighbours': 0}

# %%
SetOrder(G, imp_pq, len(G.nodes))
# Out:
# initializing importance queue settled.
# 0.08517887563884156
# 0.17035775127768313
# 0.2555366269165247
# 0.34071550255536626
# 0.42589437819420783
# 0.5110732538330494
# 0.596252129471891
# 0.6814310051107325
# 0.7666098807495741
# 0.8517887563884157
# 0.9369676320272572
# contracted completed!

# %%
edges_after = [*G.edges()]
print("# edges before", len(edges_before))
print("# edges after", len(edges_after))
# Out:
# # edges before 1417
# # edges after 2524

# %%
added_edges = list(set(edges_after) - set(edges_before))
added_edges
# Out:
# [(825, 829),
#  (321, 323),
#  (254, 256),
#  (766, 768),
#  (321, 781),
#  (69, 876),
#  (188, 246),
#  (141, 421),
#  (401, 735),
#  (536, 591),
#  (141, 145),
#  (587, 590),
#  (238, 910),
#  (181, 1031),
#  (188, 236),
#  (280, 896),
#  (101, 669),
#  (107, 141),
#  (987, 989),
#  (270, 578),
#  (409, 683),
#  (8, 482),
#  (197, 241),
#  (687, 693),
#  (47, 671),
#  (305, 309),
#  (317, 781),
#  (39, 874),
#  (768, 772),
#  (550, 910),
#  (851, 853),
#  (36, 393),
#  (440, 530),
#  (1118, 1122),
#  (238, 722),
#  (506, 508),
#  (195, 1118),
#  (193, 196),
#  (321, 324),
#  (81, 86),
#  (95, 98),
#  (69, 416),
#  (768, 937),
#  (269, 745),
#  (401, 428),
#  (259, 465),
#  (629, 903),
#  (117, 152),
#  (305, 943),
#  (77, 107),
#  (7, 137),
#  (440, 442),
#  (4, 390),
#  (236, 429),
#  (194, 725),
#  (297, 515),
#  (563, 580),
#  (317, 946),
#  (445, 448),
#  (145, 149),
#  (115, 194),
#  (246, 265),
#  (188, 193),
#  (39, 42),
#  (240, 910),
#  (221, 228),
#  (884, 1074),
#  (284, 314),
#  (343, 347),
#  (137, 173),
#  (206, 209),
#  (49, 51),
#  (297, 320),
#  (280, 401),
#  (998, 1003),
#  (109, 144),
#  (107, 416),
#  (429, 433),
#  (416, 421),
#  (409, 1025),
#  (563, 566),
#  (292, 313),
#  (194, 197),
#  (265, 760),
#  (156, 1145),
#  (47, 49),
#  (541, 561),
#  (37, 68),
#  (760, 765),
#  (412, 414),
#  (320, 335),
#  (70, 107),
#  (698, 893),
#  (424, 715),
#  (65, 411),
#  (343, 407),
#  (164, 795),
#  (126, 572),
#  (7, 37),
#  (65, 1011),
#  (297, 516),
#  (604, 640),
#  (93, 164),
#  (336, 440),
#  (160, 162),
#  (401, 465),
#  (43, 45),
#  (115, 543),
#  (56, 115),
#  (137, 416),
#  (107, 145),
#  (758, 760),
#  (233, 424),
#  (512, 1095),
#  (728, 995),
#  (236, 465),
#  (671, 674),
#  (228, 802),
#  (77, 628),
#  (394, 416),
#  (506, 752),
#  (262, 304),
#  (51, 478),
#  (86, 117),
#  (70, 72),
#  (516, 518),
#  (429, 1017),
#  (4, 17),
#  (37, 77),
#  (107, 893),
#  (277, 361),
#  (194, 246),
#  (448, 969),
#  (401, 432),
#  (196, 1118),
#  (233, 236),
#  (470, 473),
#  (13, 34),
#  (51, 284),
#  (145, 499),
#  (876, 879),
#  (758, 781),
#  (228, 837),
#  (188, 543),
#  (133, 135),
#  (577, 1166),
#  (173, 421),
#  (473, 896),
#  (768, 770),
#  (117, 120),
#  (188, 191),
#  (375, 798),
#  (115, 499),
#  (336, 959),
#  (725, 1090),
#  (37, 115),
#  (292, 304),
#  (549, 910),
#  (320, 336),
#  (321, 326),
#  (320, 959),
#  (86, 541),
#  (600, 651),
#  (36, 65),
#  (753, 910),
#  (141, 416),
#  (197, 200),
#  (197, 1118),
#  (48, 75),
#  ...]

# %%
query_list = list()
i = 0
while i < 100:
    a = random.randint(1,len(G.nodes))
    b = random.randint(1,len(G.nodes))
    pair = sorted((a,b))
    if (a==b or (pair in query_list)):
        continue
    query_list.append(pair)
    i +=1
query_list
# Out:
# [[818, 827],
#  [6, 737],
#  [304, 545],
#  [549, 873],
#  [54, 146],
#  [90, 724],
#  [557, 887],
#  [127, 922],
#  [458, 953],
#  [634, 1020],
#  [47, 1171],
#  [86, 625],
#  [128, 1150],
#  [377, 379],
#  [260, 491],
#  [26, 456],
#  [309, 630],
#  [48, 410],
#  [103, 326],
#  [191, 890],
#  [327, 392],
#  [187, 251],
#  [241, 1026],
#  [363, 864],
#  [638, 1026],
#  [525, 763],
#  [48, 1055],
#  [399, 695],
#  [98, 116],
#  [763, 1084],
#  [145, 1013],
#  [269, 386],
#  [191, 327],
#  [497, 1055],
#  [432, 1041],
#  [71, 99],
#  [146, 902],
#  [7, 467],
#  [10, 943],
#  [675, 951],
#  [453, 529],
#  [29, 829],
#  [706, 870],
#  [432, 452],
#  [300, 920],
#  [318, 353],
#  [320, 844],
#  [824, 1091],
#  [530, 555],
#  [71, 584],
#  [90, 565],
#  [168, 697],
#  [382, 781],
#  [571, 753],
#  [434, 744],
#  [208, 436],
#  [54, 64],
#  [521, 663],
#  [379, 801],
#  [170, 181],
#  [257, 964],
#  [196, 745],
#  [944, 1025],
#  [330, 830],
#  [614, 943],
#  [23, 636],
#  [501, 1159],
#  [629, 1045],
#  [60, 468],
#  [291, 346],
#  [286, 1062],
#  [112, 647],
#  [111, 227],
#  [770, 827],
#  [410, 441],
#  [351, 553],
#  [115, 546],
#  [920, 1023],
#  [439, 1066],
#  [126, 398],
#  [364, 454],
#  [349, 763],
#  [906, 1009],
#  [763, 1030],
#  [685, 1139],
#  [608, 688],
#  [619, 845],
#  [417, 510],
#  [601, 604],
#  [97, 165],
#  [129, 405],
#  [677, 785],
#  [752, 1093],
#  [172, 278],
#  [207, 959],
#  [2, 970],
#  [112, 302],
#  [58, 804],
#  [423, 1054],
#  [293, 752]]

# %%
for i in range(100):
    See_full_route(G,query_list[i][0],query_list[i][1])
# Out:
# shortest distance between source node 818 to target node 827:
# 5
# route from source node 818:
# [818, 819, 600]
# route from target node 827:
# [827, 828, 829, 600]
# entire route:
# [818, 819, 600, 829, 828, 827]
# we have skipped 1157 nodes from a graph with 1174,
#     so we have skipped 98.55195911413969% of the nodes in our search space.
#
#
#
# shortest distance between source node 6 to target node 737:
# 12
# route from source node 6:
# [6, 7, 401]
# route from target node 737:
# [737, 504, 465, 401]
# entire route:
# [6, 7, 401, 465, 504, 737]
# we have skipped 1127 nodes from a graph with 1174,
#     so we have skipped 95.99659284497444% of the nodes in our search space.
#
#
#
# shortest distance between source node 304 to target node 545:
# 22
# route from source node 304:
# [304, 280]
# route from target node 545:
# [545, 188, 236, 280]
# entire route:
# [304, 280, 236, 188, 545]
# we have skipped 1152 nodes from a graph with 1174,
#     so we have skipped 98.12606473594549% of the nodes in our search space.
#
#
#
# shortest distance between source node 549 to target node 873:
# 16
# route from source node 549:
# [549, 910, 465, 401]
# route from target node 873:
# [873, 874, 454, 7, 401]
# entire route:
# [549, 910, 465, 401, 7, 454, 874, 873]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 54 to target node 146:
# 8
# route from source node 54:
# [54, 540, 81, 115]
# route from target node 146:
# [146, 147, 148, 149, 115]
# entire route:
# [54, 540, 81, 115, 149, 148, 147, 146]
# we have skipped 1133 nodes from a graph with 1174,
#     so we have skipped 96.5076660988075% of the nodes in our search space.
#
#
#
# shortest distance between source node 90 to target node 724:
# 31
# route from source node 90:
# [90, 800, 802, 277, 280]
# route from target node 724:
# [724, 722, 236, 280]
# entire route:
# [90, 800, 802, 277, 280, 236, 722, 724]
# we have skipped 1139 nodes from a graph with 1174,
#     so we have skipped 97.01873935264055% of the nodes in our search space.
#
#
#
# shortest distance between source node 557 to target node 887:
# 22
# route from source node 557:
# [557, 558, 515, 297, 284, 401]
# route from target node 887:
# [887, 686, 687, 141, 401]
# entire route:
# [557, 558, 515, 297, 284, 401, 141, 687, 686, 887]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 127 to target node 922:
# no path between source node 127 to target node 922
# shortest distance between source node 458 to target node 953:
# 24
# route from source node 458:
# [458, 459, 141, 401]
# route from target node 953:
# [953, 442, 440, 321, 284, 401]
# entire route:
# [458, 459, 141, 401, 284, 321, 440, 442, 953]
# we have skipped 1134 nodes from a graph with 1174,
#     so we have skipped 96.59284497444634% of the nodes in our search space.
#
#
#
# shortest distance between source node 634 to target node 1020:
# 23
# route from source node 634:
# [634, 604, 277, 280]
# route from target node 1020:
# [1020, 433, 280]
# entire route:
# [634, 604, 277, 280, 433, 1020]
# we have skipped 1135 nodes from a graph with 1174,
#     so we have skipped 96.67802385008518% of the nodes in our search space.
#
#
#
# shortest distance between source node 47 to target node 1171:
# 25
# route from source node 47:
# [47, 107]
# route from target node 1171:
# [1171, 212, 577, 246, 188, 107]
# entire route:
# [47, 107, 188, 246, 577, 212, 1171]
# we have skipped 1151 nodes from a graph with 1174,
#     so we have skipped 98.04088586030664% of the nodes in our search space.
#
#
#
# shortest distance between source node 86 to target node 625:
# no path between source node 86 to target node 625
# shortest distance between source node 128 to target node 1150:
# no path between source node 128 to target node 1150
# shortest distance between source node 377 to target node 379:
# no path between source node 377 to target node 379
# shortest distance between source node 260 to target node 491:
# 15
# route from source node 260:
# [260, 259, 465, 499]
# route from target node 491:
# [491, 674, 107, 499]
# entire route:
# [260, 259, 465, 499, 107, 674, 491]
# we have skipped 1127 nodes from a graph with 1174,
#     so we have skipped 95.99659284497444% of the nodes in our search space.
#
#
#
# shortest distance between source node 26 to target node 456:
# 8
# route from source node 26:
# [26, 27, 561, 7]
# route from target node 456:
# [456, 43, 7]
# entire route:
# [26, 27, 561, 7, 43, 456]
# we have skipped 1135 nodes from a graph with 1174,
#     so we have skipped 96.67802385008518% of the nodes in our search space.
#
#
#
# shortest distance between source node 309 to target node 630:
# 27
# route from source node 309:
# [309, 305, 304, 280, 401]
# route from target node 630:
# [630, 69, 633, 137, 401]
# entire route:
# [309, 305, 304, 280, 401, 137, 633, 69, 630]
# we have skipped 1144 nodes from a graph with 1174,
#     so we have skipped 97.44463373083475% of the nodes in our search space.
#
#
#
# shortest distance between source node 48 to target node 410:
# 5
# route from source node 48:
# [48, 49, 43]
# route from target node 410:
# [410, 411, 43]
# entire route:
# [48, 49, 43, 411, 410]
# we have skipped 1126 nodes from a graph with 1174,
#     so we have skipped 95.9114139693356% of the nodes in our search space.
#
#
#
# shortest distance between source node 103 to target node 326:
# 20
# route from source node 103:
# [103, 101, 137, 401]
# route from target node 326:
# [326, 321, 284, 401]
# entire route:
# [103, 101, 137, 401, 284, 321, 326]
# we have skipped 1133 nodes from a graph with 1174,
#     so we have skipped 96.5076660988075% of the nodes in our search space.
#
#
#
# shortest distance between source node 191 to target node 890:
# 10
# route from source node 191:
# [191, 190, 543, 145, 107]
# route from target node 890:
# [890, 674, 107]
# entire route:
# [191, 190, 543, 145, 107, 674, 890]
# we have skipped 1133 nodes from a graph with 1174,
#     so we have skipped 96.5076660988075% of the nodes in our search space.
#
#
#
# shortest distance between source node 327 to target node 392:
# 21
# route from source node 327:
# [327, 321, 284, 7]
# route from target node 392:
# [392, 393, 65, 411, 7]
# entire route:
# [327, 321, 284, 7, 411, 65, 393, 392]
# we have skipped 1139 nodes from a graph with 1174,
#     so we have skipped 97.01873935264055% of the nodes in our search space.
#
#
#
# shortest distance between source node 187 to target node 251:
# no path between source node 187 to target node 251
# shortest distance between source node 241 to target node 1026:
# 14
# route from source node 241:
# [241, 188, 499]
# route from target node 1026:
# [1026, 682, 683, 141, 499]
# entire route:
# [241, 188, 499, 141, 683, 682, 1026]
# we have skipped 1138 nodes from a graph with 1174,
#     so we have skipped 96.9335604770017% of the nodes in our search space.
#
#
#
# shortest distance between source node 363 to target node 864:
# 20
# route from source node 363:
# [363, 361, 277, 401]
# route from target node 864:
# [864, 173, 424, 401]
# entire route:
# [363, 361, 277, 401, 424, 173, 864]
# we have skipped 1141 nodes from a graph with 1174,
#     so we have skipped 97.18909710391823% of the nodes in our search space.
#
#
#
# shortest distance between source node 638 to target node 1026:
# 32
# route from source node 638:
# [638, 604, 277, 401]
# route from target node 1026:
# [1026, 682, 137, 401]
# entire route:
# [638, 604, 277, 401, 137, 682, 1026]
# we have skipped 1144 nodes from a graph with 1174,
#     so we have skipped 97.44463373083475% of the nodes in our search space.
#
#
#
# shortest distance between source node 525 to target node 763:
# 23
# route from source node 525:
# [525, 523, 321, 280]
# route from target node 763:
# [763, 760, 758, 280]
# entire route:
# [525, 523, 321, 280, 758, 760, 763]
# we have skipped 1139 nodes from a graph with 1174,
#     so we have skipped 97.01873935264055% of the nodes in our search space.
#
#
#
# shortest distance between source node 48 to target node 1055:
# no path between source node 48 to target node 1055
# shortest distance between source node 399 to target node 695:
# 7
# route from source node 399:
# [399, 682, 683, 107]
# route from target node 695:
# [695, 107]
# entire route:
# [399, 682, 683, 107, 695]
# we have skipped 1149 nodes from a graph with 1174,
#     so we have skipped 97.87052810902897% of the nodes in our search space.
#
#
#
# shortest distance between source node 98 to target node 116:
# 15
# route from source node 98:
# [98, 99, 100, 633, 411, 7]
# route from target node 116:
# [116, 84, 86, 561, 7]
# entire route:
# [98, 99, 100, 633, 411, 7, 561, 86, 84, 116]
# we have skipped 1140 nodes from a graph with 1174,
#     so we have skipped 97.10391822827938% of the nodes in our search space.
#
#
#
# shortest distance between source node 763 to target node 1084:
# 22
# route from source node 763:
# [763, 764, 765, 766, 246, 194]
# route from target node 1084:
# [1084, 1085, 1086, 1087, 1088, 1089, 1090, 725, 194]
# entire route:
# [763, 764, 765, 766, 246, 194, 725, 1090, 1089, 1088, 1087, 1086, 1085, 1084]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 145 to target node 1013:
# 12
# route from source node 145:
# [145, 107, 37]
# route from target node 1013:
# [1013, 1011, 37]
# entire route:
# [145, 107, 37, 1011, 1013]
# we have skipped 1148 nodes from a graph with 1174,
#     so we have skipped 97.78534923339012% of the nodes in our search space.
#
#
#
# shortest distance between source node 269 to target node 386:
# no path between source node 269 to target node 386
# shortest distance between source node 191 to target node 327:
# 24
# route from source node 191:
# [191, 188, 236, 280]
# route from target node 327:
# [327, 321, 280]
# entire route:
# [191, 188, 236, 280, 321, 327]
# we have skipped 1136 nodes from a graph with 1174,
#     so we have skipped 96.76320272572401% of the nodes in our search space.
#
#
#
# shortest distance between source node 497 to target node 1055:
# no path between source node 497 to target node 1055
# shortest distance between source node 432 to target node 1041:
# 12
# route from source node 432:
# [432, 465, 499]
# route from target node 1041:
# [1041, 107, 499]
# entire route:
# [432, 465, 499, 107, 1041]
# we have skipped 1141 nodes from a graph with 1174,
#     so we have skipped 97.18909710391823% of the nodes in our search space.
#
#
#
# shortest distance between source node 71 to target node 99:
# 5
# route from source node 71:
# [71, 70]
# route from target node 99:
# [99, 100, 633, 70]
# entire route:
# [71, 70, 633, 100, 99]
# we have skipped 1146 nodes from a graph with 1174,
#     so we have skipped 97.61499148211243% of the nodes in our search space.
#
#
#
# shortest distance between source node 146 to target node 902:
# 9
# route from source node 146:
# [146, 147, 148, 149, 115]
# route from target node 902:
# [902, 903, 904, 81, 115]
# entire route:
# [146, 147, 148, 149, 115, 81, 904, 903, 902]
# we have skipped 1132 nodes from a graph with 1174,
#     so we have skipped 96.42248722316864% of the nodes in our search space.
#
#
#
# shortest distance between source node 7 to target node 467:
# 10
# route from source node 7:
# [7]
# route from target node 467:
# [467, 468, 280, 7]
# entire route:
# [7, 280, 468, 467]
# we have skipped 1140 nodes from a graph with 1174,
#     so we have skipped 97.10391822827938% of the nodes in our search space.
#
#
#
# shortest distance between source node 10 to target node 943:
# 23
# route from source node 10:
# [10, 9, 7]
# route from target node 943:
# [943, 305, 304, 284, 7]
# entire route:
# [10, 9, 7, 284, 304, 305, 943]
# we have skipped 1131 nodes from a graph with 1174,
#     so we have skipped 96.33730834752981% of the nodes in our search space.
#
#
#
# shortest distance between source node 675 to target node 951:
# 24
# route from source node 675:
# [675, 489, 490, 674, 47, 7]
# route from target node 951:
# [951, 523, 321, 284, 7]
# entire route:
# [675, 489, 490, 674, 47, 7, 284, 321, 523, 951]
# we have skipped 1134 nodes from a graph with 1174,
#     so we have skipped 96.59284497444634% of the nodes in our search space.
#
#
#
# shortest distance between source node 453 to target node 529:
# 16
# route from source node 453:
# [453, 403, 284]
# route from target node 529:
# [529, 440, 321, 284]
# entire route:
# [453, 403, 284, 321, 440, 529]
# we have skipped 1139 nodes from a graph with 1174,
#     so we have skipped 97.01873935264055% of the nodes in our search space.
#
#
#
# shortest distance between source node 29 to target node 829:
# 33
# route from source node 29:
# [29, 27, 561, 7]
# route from target node 829:
# [829, 600, 277, 284, 7]
# entire route:
# [29, 27, 561, 7, 284, 277, 600, 829]
# we have skipped 1143 nodes from a graph with 1174,
#     so we have skipped 97.35945485519592% of the nodes in our search space.
#
#
#
# shortest distance between source node 706 to target node 870:
# 18
# route from source node 706:
# [706, 707, 708, 225, 228, 277, 284]
# route from target node 870:
# [870, 320, 297, 284]
# entire route:
# [706, 707, 708, 225, 228, 277, 284, 297, 320, 870]
# we have skipped 1133 nodes from a graph with 1174,
#     so we have skipped 96.5076660988075% of the nodes in our search space.
#
#
#
# shortest distance between source node 432 to target node 452:
# 4
# route from source node 432:
# [432, 401]
# route from target node 452:
# [452, 402, 401]
# entire route:
# [432, 401, 402, 452]
# we have skipped 1140 nodes from a graph with 1174,
#     so we have skipped 97.10391822827938% of the nodes in our search space.
#
#
#
# shortest distance between source node 300 to target node 920:
# 22
# route from source node 300:
# [300, 299, 314, 284, 7]
# route from target node 920:
# [920, 919, 918, 12, 561, 7]
# entire route:
# [300, 299, 314, 284, 7, 561, 12, 918, 919, 920]
# we have skipped 1132 nodes from a graph with 1174,
#     so we have skipped 96.42248722316864% of the nodes in our search space.
#
#
#
# shortest distance between source node 318 to target node 353:
# 16
# route from source node 318:
# [318, 317, 321]
# route from target node 353:
# [353, 407, 320, 321]
# entire route:
# [318, 317, 321, 320, 407, 353]
# we have skipped 1145 nodes from a graph with 1174,
#     so we have skipped 97.5298126064736% of the nodes in our search space.
#
#
#
# shortest distance between source node 320 to target node 844:
# 24
# route from source node 320:
# [320, 297, 284]
# route from target node 844:
# [844, 795, 798, 800, 802, 277, 284]
# entire route:
# [320, 297, 284, 277, 802, 800, 798, 795, 844]
# we have skipped 1140 nodes from a graph with 1174,
#     so we have skipped 97.10391822827938% of the nodes in our search space.
#
#
#
# shortest distance between source node 824 to target node 1091:
# 43
# route from source node 824:
# [824, 825, 600, 277, 280]
# route from target node 1091:
# [1091, 725, 236, 280]
# entire route:
# [824, 825, 600, 277, 280, 236, 725, 1091]
# we have skipped 1142 nodes from a graph with 1174,
#     so we have skipped 97.27427597955707% of the nodes in our search space.
#
#
#
# shortest distance between source node 530 to target node 555:
# 21
# route from source node 530:
# [530, 440, 321]
# route from target node 555:
# [555, 556, 557, 558, 515, 297, 321]
# entire route:
# [530, 440, 321, 297, 515, 558, 557, 556, 555]
# we have skipped 1138 nodes from a graph with 1174,
#     so we have skipped 96.9335604770017% of the nodes in our search space.
#
#
#
# shortest distance between source node 71 to target node 584:
# 22
# route from source node 71:
# [71, 72, 671, 107]
# route from target node 584:
# [584, 581, 563, 188, 107]
# entire route:
# [71, 72, 671, 107, 188, 563, 581, 584]
# we have skipped 1138 nodes from a graph with 1174,
#     so we have skipped 96.9335604770017% of the nodes in our search space.
#
#
#
# shortest distance between source node 90 to target node 565:
# 32
# route from source node 90:
# [90, 800, 802, 277, 280]
# route from target node 565:
# [565, 563, 910, 465, 280]
# entire route:
# [90, 800, 802, 277, 280, 465, 910, 563, 565]
# we have skipped 1140 nodes from a graph with 1174,
#     so we have skipped 97.10391822827938% of the nodes in our search space.
#
#
#
# shortest distance between source node 168 to target node 697:
# 10
# route from source node 168:
# [168, 169, 137, 141, 499]
# route from target node 697:
# [697, 698, 499]
# entire route:
# [168, 169, 137, 141, 499, 698, 697]
# we have skipped 1132 nodes from a graph with 1174,
#     so we have skipped 96.42248722316864% of the nodes in our search space.
#
#
#
# shortest distance between source node 382 to target node 781:
# no path between source node 382 to target node 781
# shortest distance between source node 571 to target node 753:
# 12
# route from source node 571:
# [571, 567, 563]
# route from target node 753:
# [753, 550, 241, 563]
# entire route:
# [571, 567, 563, 241, 550, 753]
# we have skipped 1139 nodes from a graph with 1174,
#     so we have skipped 97.01873935264055% of the nodes in our search space.
#
#
#
# shortest distance between source node 434 to target node 744:
# 13
# route from source node 434:
# [434, 433, 465]
# route from target node 744:
# [744, 745, 563, 910, 465]
# entire route:
# [434, 433, 465, 910, 563, 745, 744]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 208 to target node 436:
# 25
# route from source node 208:
# [208, 206, 204, 246, 465, 280]
# route from target node 436:
# [436, 321, 280]
# entire route:
# [208, 206, 204, 246, 465, 280, 321, 436]
# we have skipped 1142 nodes from a graph with 1174,
#     so we have skipped 97.27427597955707% of the nodes in our search space.
#
#
#
# shortest distance between source node 54 to target node 64:
# 6
# route from source node 54:
# [54, 629, 43]
# route from target node 64:
# [64, 411, 43]
# entire route:
# [54, 629, 43, 411, 64]
# we have skipped 1135 nodes from a graph with 1174,
#     so we have skipped 96.67802385008518% of the nodes in our search space.
#
#
#
# shortest distance between source node 521 to target node 663:
# 39
# route from source node 521:
# [521, 522, 316, 314, 284]
# route from target node 663:
# [663, 664, 665, 824, 825, 600, 277, 284]
# entire route:
# [521, 522, 316, 314, 284, 277, 600, 825, 824, 665, 664, 663]
# we have skipped 1140 nodes from a graph with 1174,
#     so we have skipped 97.10391822827938% of the nodes in our search space.
#
#
#
# shortest distance between source node 379 to target node 801:
# no path between source node 379 to target node 801
# shortest distance between source node 170 to target node 181:
# 7
# route from source node 170:
# [170, 171, 400, 401]
# route from target node 181:
# [181, 233, 401]
# entire route:
# [170, 171, 400, 401, 233, 181]
# we have skipped 1141 nodes from a graph with 1174,
#     so we have skipped 97.18909710391823% of the nodes in our search space.
#
#
#
# shortest distance between source node 257 to target node 964:
# 23
# route from source node 257:
# [257, 254, 403, 284]
# route from target node 964:
# [964, 959, 320, 297, 284]
# entire route:
# [257, 254, 403, 284, 297, 320, 959, 964]
# we have skipped 1134 nodes from a graph with 1174,
#     so we have skipped 96.59284497444634% of the nodes in our search space.
#
#
#
# shortest distance between source node 196 to target node 745:
# 3
# route from source node 196:
# [196, 241, 563]
# route from target node 745:
# [745, 563]
# entire route:
# [196, 241, 563, 745]
# we have skipped 1143 nodes from a graph with 1174,
#     so we have skipped 97.35945485519592% of the nodes in our search space.
#
#
#
# shortest distance between source node 944 to target node 1025:
# 25
# route from source node 944:
# [944, 305, 304, 284, 7]
# route from target node 1025:
# [1025, 409, 7]
# entire route:
# [944, 305, 304, 284, 7, 409, 1025]
# we have skipped 1139 nodes from a graph with 1174,
#     so we have skipped 97.01873935264055% of the nodes in our search space.
#
#
#
# shortest distance between source node 330 to target node 830:
# 27
# route from source node 330:
# [330, 329, 407, 284]
# route from target node 830:
# [830, 831, 375, 800, 802, 277, 284]
# entire route:
# [330, 329, 407, 284, 277, 802, 800, 375, 831, 830]
# we have skipped 1128 nodes from a graph with 1174,
#     so we have skipped 96.08177172061329% of the nodes in our search space.
#
#
#
# shortest distance between source node 614 to target node 943:
# 22
# route from source node 614:
# [614, 217, 277, 284]
# route from target node 943:
# [943, 305, 304, 284]
# entire route:
# [614, 217, 277, 284, 304, 305, 943]
# we have skipped 1142 nodes from a graph with 1174,
#     so we have skipped 97.27427597955707% of the nodes in our search space.
#
#
#
# shortest distance between source node 23 to target node 636:
# 28
# route from source node 23:
# [23, 7]
# route from target node 636:
# [636, 604, 277, 284, 7]
# entire route:
# [23, 7, 284, 277, 604, 636]
# we have skipped 1148 nodes from a graph with 1174,
#     so we have skipped 97.78534923339012% of the nodes in our search space.
#
#
#
# shortest distance between source node 501 to target node 1159:
# 19
# route from source node 501:
# [501, 236, 401]
# route from target node 1159:
# [1159, 34, 13, 12, 561, 7, 401]
# entire route:
# [501, 236, 401, 7, 561, 12, 13, 34, 1159]
# we have skipped 1156 nodes from a graph with 1174,
#     so we have skipped 98.46678023850085% of the nodes in our search space.
#
#
#
# shortest distance between source node 629 to target node 1045:
# 13
# route from source node 629:
# [629, 43]
# route from target node 1045:
# [1045, 460, 180, 141, 43]
# entire route:
# [629, 43, 141, 180, 460, 1045]
# we have skipped 1122 nodes from a graph with 1174,
#     so we have skipped 95.57069846678023% of the nodes in our search space.
#
#
#
# shortest distance between source node 60 to target node 468:
# no path between source node 60 to target node 468
# shortest distance between source node 291 to target node 346:
# 13
# route from source node 291:
# [291, 284]
# route from target node 346:
# [346, 343, 407, 284]
# entire route:
# [291, 284, 407, 343, 346]
# we have skipped 1142 nodes from a graph with 1174,
#     so we have skipped 97.27427597955707% of the nodes in our search space.
#
#
#
# shortest distance between source node 286 to target node 1062:
# 7
# route from source node 286:
# [286, 287, 280]
# route from target node 1062:
# [1062, 1063, 1064, 896, 280]
# entire route:
# [286, 287, 280, 896, 1064, 1063, 1062]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 112 to target node 647:
# no path between source node 112 to target node 647
# shortest distance between source node 111 to target node 227:
# 21
# route from source node 111:
# [111, 112, 145, 499, 401]
# route from target node 227:
# [227, 228, 277, 401]
# entire route:
# [111, 112, 145, 499, 401, 277, 228, 227]
# we have skipped 1144 nodes from a graph with 1174,
#     so we have skipped 97.44463373083475% of the nodes in our search space.
#
#
#
# shortest distance between source node 770 to target node 827:
# 45
# route from source node 770:
# [770, 768, 758, 280]
# route from target node 827:
# [827, 828, 829, 600, 277, 280]
# entire route:
# [770, 768, 758, 280, 277, 600, 829, 828, 827]
# we have skipped 1142 nodes from a graph with 1174,
#     so we have skipped 97.27427597955707% of the nodes in our search space.
#
#
#
# shortest distance between source node 410 to target node 441:
# 18
# route from source node 410:
# [410, 411, 7]
# route from target node 441:
# [441, 440, 321, 284, 7]
# entire route:
# [410, 411, 7, 284, 321, 440, 441]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 351 to target node 553:
# 20
# route from source node 351:
# [351, 407, 284, 280]
# route from target node 553:
# [553, 554, 512, 758, 280]
# entire route:
# [351, 407, 284, 280, 758, 512, 554, 553]
# we have skipped 1134 nodes from a graph with 1174,
#     so we have skipped 96.59284497444634% of the nodes in our search space.
#
#
#
# shortest distance between source node 115 to target node 546:
# 6
# route from source node 115:
# [115]
# route from target node 546:
# [546, 188, 115]
# entire route:
# [115, 188, 546]
# we have skipped 1149 nodes from a graph with 1174,
#     so we have skipped 97.87052810902897% of the nodes in our search space.
#
#
#
# shortest distance between source node 920 to target node 1023:
# 13
# route from source node 920:
# [920, 919, 918, 12, 561, 7]
# route from target node 1023:
# [1023, 884, 885, 7]
# entire route:
# [920, 919, 918, 12, 561, 7, 885, 884, 1023]
# we have skipped 1131 nodes from a graph with 1174,
#     so we have skipped 96.33730834752981% of the nodes in our search space.
#
#
#
# shortest distance between source node 439 to target node 1066:
# 13
# route from source node 439:
# [439, 321, 280]
# route from target node 1066:
# [1066, 1067, 468, 280]
# entire route:
# [439, 321, 280, 468, 1067, 1066]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 126 to target node 398:
# no path between source node 126 to target node 398
# shortest distance between source node 364 to target node 454:
# 20
# route from source node 364:
# [364, 802, 277, 284, 7]
# route from target node 454:
# [454, 7]
# entire route:
# [364, 802, 277, 284, 7, 454]
# we have skipped 1144 nodes from a graph with 1174,
#     so we have skipped 97.44463373083475% of the nodes in our search space.
#
#
#
# shortest distance between source node 349 to target node 763:
# 26
# route from source node 349:
# [349, 347, 336, 320, 297, 280]
# route from target node 763:
# [763, 760, 758, 280]
# entire route:
# [349, 347, 336, 320, 297, 280, 758, 760, 763]
# we have skipped 1134 nodes from a graph with 1174,
#     so we have skipped 96.59284497444634% of the nodes in our search space.
#
#
#
# shortest distance between source node 906 to target node 1009:
# 12
# route from source node 906:
# [906, 145, 499, 401]
# route from target node 1009:
# [1009, 253, 401]
# entire route:
# [906, 145, 499, 401, 253, 1009]
# we have skipped 1135 nodes from a graph with 1174,
#     so we have skipped 96.67802385008518% of the nodes in our search space.
#
#
#
# shortest distance between source node 763 to target node 1030:
# 19
# route from source node 763:
# [763, 760, 265, 236]
# route from target node 1030:
# [1030, 177, 715, 1031, 181, 236]
# entire route:
# [763, 760, 265, 236, 181, 1031, 715, 177, 1030]
# we have skipped 1127 nodes from a graph with 1174,
#     so we have skipped 95.99659284497444% of the nodes in our search space.
#
#
#
# shortest distance between source node 685 to target node 1139:
# 14
# route from source node 685:
# [685, 683, 7]
# route from target node 1139:
# [1139, 536, 10, 9, 7]
# entire route:
# [685, 683, 7, 9, 10, 536, 1139]
# we have skipped 1130 nodes from a graph with 1174,
#     so we have skipped 96.25212947189097% of the nodes in our search space.
#
#
#
# shortest distance between source node 608 to target node 688:
# 25
# route from source node 608:
# [608, 800, 802, 277, 401]
# route from target node 688:
# [688, 499, 401]
# entire route:
# [608, 800, 802, 277, 401, 499, 688]
# we have skipped 1147 nodes from a graph with 1174,
#     so we have skipped 97.70017035775128% of the nodes in our search space.
#
#
#
# shortest distance between source node 619 to target node 845:
# 13
# route from source node 619:
# [619, 1139, 536, 10, 9, 7, 401]
# route from target node 845:
# [845, 711, 401]
# entire route:
# [619, 1139, 536, 10, 9, 7, 401, 711, 845]
# we have skipped 1132 nodes from a graph with 1174,
#     so we have skipped 96.42248722316864% of the nodes in our search space.
#
#
#
# shortest distance between source node 417 to target node 510:
# 16
# route from source node 417:
# [417, 70, 137, 401]
# route from target node 510:
# [510, 262, 465, 401]
# entire route:
# [417, 70, 137, 401, 465, 262, 510]
# we have skipped 1136 nodes from a graph with 1174,
#     so we have skipped 96.76320272572401% of the nodes in our search space.
#
#
#
# shortest distance between source node 601 to target node 604:
# 3
# route from source node 601:
# [601, 602, 603, 604]
# route from target node 604:
# [604]
# entire route:
# [601, 602, 603, 604]
# we have skipped 1160 nodes from a graph with 1174,
#     so we have skipped 98.80749574105621% of the nodes in our search space.
#
#
#
# shortest distance between source node 97 to target node 165:
# 33
# route from source node 97:
# [97, 98, 99, 100, 137, 401]
# route from target node 165:
# [165, 164, 800, 802, 277, 401]
# entire route:
# [97, 98, 99, 100, 137, 401, 277, 802, 800, 164, 165]
# we have skipped 1138 nodes from a graph with 1174,
#     so we have skipped 96.9335604770017% of the nodes in our search space.
#
#
#
# shortest distance between source node 129 to target node 405:
# 25
# route from source node 129:
# [129, 130, 164, 800, 802, 277, 284]
# route from target node 405:
# [405, 284]
# entire route:
# [129, 130, 164, 800, 802, 277, 284, 405]
# we have skipped 1139 nodes from a graph with 1174,
#     so we have skipped 97.01873935264055% of the nodes in our search space.
#
#
#
# shortest distance between source node 677 to target node 785:
# 19
# route from source node 677:
# [677, 77, 7]
# route from target node 785:
# [785, 298, 297, 284, 7]
# entire route:
# [677, 77, 7, 284, 297, 298, 785]
# we have skipped 1133 nodes from a graph with 1174,
#     so we have skipped 96.5076660988075% of the nodes in our search space.
#
#
#
# shortest distance between source node 752 to target node 1093:
# no path between source node 752 to target node 1093
# shortest distance between source node 172 to target node 278:
# 6
# route from source node 172:
# [172, 171, 400, 401]
# route from target node 278:
# [278, 711, 401]
# entire route:
# [172, 171, 400, 401, 711, 278]
# we have skipped 1136 nodes from a graph with 1174,
#     so we have skipped 96.76320272572401% of the nodes in our search space.
#
#
#
# shortest distance between source node 207 to target node 959:
# 34
# route from source node 207:
# [207, 206, 204, 246, 465, 280]
# route from target node 959:
# [959, 320, 297, 280]
# entire route:
# [207, 206, 204, 246, 465, 280, 297, 320, 959]
# we have skipped 1142 nodes from a graph with 1174,
#     so we have skipped 97.27427597955707% of the nodes in our search space.
#
#
#
# shortest distance between source node 2 to target node 970:
# no path between source node 2 to target node 970
# shortest distance between source node 112 to target node 302:
# 23
# route from source node 112:
# [112, 145, 499]
# route from target node 302:
# [302, 299, 314, 292, 280, 499]
# entire route:
# [112, 145, 499, 280, 292, 314, 299, 302]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.
#
#
#
# shortest distance between source node 58 to target node 804:
# no path between source node 58 to target node 804
# shortest distance between source node 423 to target node 1054:
# no path between source node 423 to target node 1054
# shortest distance between source node 293 to target node 752:
# 11
# route from source node 293:
# [293, 292, 280]
# route from target node 752:
# [752, 753, 265, 280]
# entire route:
# [293, 292, 280, 265, 753, 752]
# we have skipped 1137 nodes from a graph with 1174,
#     so we have skipped 96.84838160136286% of the nodes in our search space.

# %%
G_original = nx.Graph()
graph = open("road-euroroad.txt","r")
Connect(G_original,graph)
has_path_list = list()
# Out:
# 1174
# 1417

# %%
def See_full_route_constract(G, s, t):
    minimum, merge_node, SP_s, SP_t, parent_s, parent_t = GetDistance(G, s, t)
    # print("shortest distance between source node %d to target node %d:"%(s,t))
    if minimum == math.inf:
        print("no path between source node %d to target node %d"%(s,t))
        return
    # has_path_list.append([s,t])
    # print(minimum)
    route_from_source = Route_dijkstra(parent_s, merge_node)
    # show route
    # print("route from source node %d:"%s)
    # print(route_from_source)
    route_from_target = Route_dijkstra(parent_t, merge_node)
    # show route
    # print("route from target node %d:"%t)
    # print(route_from_target)
    route = route_from_source + route_from_target[::-1][1:]
    # show route
    # print("entire route:")
    # print(route)
    # unvisited = 0
    # for s_node, s_dist in SP_s.items():
    #     for t_node, t_dist in SP_t.items():
    #         if s_node == t_node and s_dist == t_dist == math.inf:
    #             unvisited += 1
    # print(f"""we have skipped {unvisited} nodes from a graph with {len(G)}, 
    # so we have skipped {unvisited/len(G)*100}% of the nodes in our search space.""")
    # print("\n\n")
    # print([minimum, route])

# %%
def dijkstra_with_contraction(G, source, destination, contracted = None):
    nx.set_node_attributes(G, {contracted: True}, 'contracted')
    
        
    shortest_path = dict()
    heap = list()
    
    for i in G.nodes():
        if not nx.get_node_attributes(G, 'contracted')[i]:
            shortest_path[i] = math.inf
            heap.append(i)
    shortest_path[source] = 0
    
    while len(heap)>0:
        q = min(heap, key= lambda node : shortest_path[node])
        if q == destination:
            nx.set_node_attributes(G, {contracted: False}, 'contracted')
            return shortest_path[q]
        heap.remove(q)
        # G[q] are incident edges of q
        for v in G[q]:
            # if the node is contracted, skip it
            if not nx.get_node_attributes(G, 'contracted')[v]:
                distance = shortest_path[q] + G[q][v]['weight']
                if distance < shortest_path[v]:
                    shortest_path[v] = distance
    nx.set_node_attributes(G, {contracted: False}, 'contracted')
    
    # can not reach the destination
    return math.inf

# %%
from networkx.algorithms.shortest_paths.weighted import single_source_dijkstra
sd_a = datetime.datetime.now()
for i in range(len(query_list)):
    distance = dijkstra_with_contraction(G_original, query_list[i][0], query_list[i][1])
sd_b = datetime.datetime.now()
((sd_b - sd_a).total_seconds())/len(query_list)
# Out:
# 1.4417042599999998

# %%
ch_a = datetime.datetime.now()
for i in range(len(query_list)):
    See_full_route_constract(G, query_list[i][0], query_list[i][1])
ch_b = datetime.datetime.now()
((ch_b - ch_a).total_seconds())/len(query_list)
# Out:
# no path between source node 127 to target node 922
# no path between source node 86 to target node 625
# no path between source node 128 to target node 1150
# no path between source node 377 to target node 379
# no path between source node 187 to target node 251
# no path between source node 48 to target node 1055
# no path between source node 269 to target node 386
# no path between source node 497 to target node 1055
# no path between source node 382 to target node 781
# no path between source node 379 to target node 801
# no path between source node 60 to target node 468
# no path between source node 112 to target node 647
# no path between source node 126 to target node 398
# no path between source node 752 to target node 1093
# no path between source node 2 to target node 970
# no path between source node 58 to target node 804
# no path between source node 423 to target node 1054
# 0.00838953
